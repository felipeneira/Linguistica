# %%
# =============================================================================
# Librerías
# =============================================================================
import glob
import string
import re
import pandas as pd
# =============================================================================
# 
# =============================================================================
##generamos una def para eliminar los puntos
def remover_puntuacion(s):
    ##cada uno de los items que aparecen en esta lista
    for c in string.punctuation:
        ##es eliminado del texto reemplazandolo por un espacio vacÃ­o
        s=s.replace(c,"")
        ##lo mismo se hace con "\t"
        s=s.replace('\t','')
    return s

##Ãºltima def de preparacion
def remover_numeros(k):
    ##por cada item dentro de la lusta numeros
    for z in str(list(range(100))):
        ##reemplazamos elitem de la lista con un vacÃ­o
        k=k.replace(z," ")
        ##tambiÃ©n eliminamos la palabra "pag", usada para marcar pÃ¡ginas junto con lo anterior
        k=k.replace('pag','')
    return k

## función para detectar k palabras anteriores

def k_anteriores(oracion,Y,k):
    lista_contextos = []
    for i in range(len(oracion)):
        word = oracion[i]
        if word == Y:
            r = k
            for r in range(1,k+1):
                if i-r < 0:
                    r -= 1
            lista_contextos += [oracion[i-r:i]+[Y]]
    return lista_contextos
# =============================================================================
# 
# =============================================================================
lista_files = glob.glob('/home/felipe/Documentos/GitHub/Linguistica/YEM/entrevistas_mineduc/*.txt')
corpus = {}
##por cada archivo en la lista de archivos
for file in lista_files:
##este se abre con encoding utf-8 y queda definido como file_input
    with open(file, 'r', encoding="utf-8") as file_input:
##se toman los nombres de los textos y se le quitan los primeros 15 caracteres (el nombre de la carpeta)
        corpus[file[67:-4]]=file_input.read()
corpus_string = str(corpus)
print('Nombre de los textos')
print(corpus.keys())
re_traduccion = r"n*M:\s*([a-zA-Z\<\>\d\s\?\¿ñÑü\.\*\%\,\\\'\áéíóú\'\!\\-¡]*)\\*\\nC:\s*([a-zA-Z\<\>\d\s\?\¿ñü\.\*\%\,\\\'\áéíóú]*)\\*\\n*"
corpus= re.findall(re_traduccion,corpus_string)
mapu= []
espa= []
for lista in corpus:
    mapu += lista[0:1]
    espa += lista[1:2]
string_corpus_misional = str(mapu)
##Tomamos el string_corpus_misional y limpiamos una serie de impurezas tÃ­picas de la escritura en mapudungun y el trabajo con txt
##En primer lugar eliminamos los saltos de pÃ¡gina marcados con "\n" y los marcados con "\t"
string_corpus_contextos = string_corpus_misional.replace('\n', ' ')
string_corpus_contextos = string_corpus_contextos.replace('\t', ' ')
##luego eliminamos [r], que simboliza la duda del escritor sobre la existencia de una "r" en esa posicion
string_corpus_contextos = string_corpus_contextos.replace('[r]', 'r')
##eliminamos los marcadores de pÃ¡rrafo 
string_corpus_contextos = string_corpus_contextos.replace('Â¶', '')
##utilizamos ambas def para eliminar puntuaciones y nÃºmeros del texto
string_corpus_contextos = remover_numeros(string_corpus_contextos)
##eliminamos las marcas de pregunta y respuesta en el texto, las que son marcadas con una "P" y "R" en el corpus
string_corpus_contextos = string_corpus_contextos.replace('P ', '')
string_corpus_contextos = string_corpus_contextos.replace('R ', '')
##eliminamos las mayÃºsculas y el exceso de espacios
string_corpus_contextos = string_corpus_contextos.lower()
##luego se usa .split para dividir el texto por \n
string_corpus_misional = string_corpus_misional.replace('\n', '')
string_corpus_contextos = string_corpus_contextos.replace('Â¿', '')
string_corpus_contextos = string_corpus_contextos.replace('â', '')
string_corpus_contextos = string_corpus_contextos.replace('â¦', '')
string_corpus_contextos = re.sub('<\*spa>',' ',string_corpus_contextos)
string_corpus_contextos = remover_puntuacion(string_corpus_contextos)
string_corpus_contextos = string_corpus_contextos.strip()
##lista exclusiva para graficacion
lista_corpus_contextos = string_corpus_contextos.split(' ')
tokens = []
for item in lista_corpus_contextos:    
    if len(item) > 0:
        tokens+= [item]
# Out:
# Nombre de los textos
# dict_keys(['nmlch-pmgmm2', 'nmlch-lmeh1', 'nmlch-lmmccB1', 'nmlch-pmmhh1', 'nmlch-pmareB2', 'nmlch-lfjpl2', 'nmlch-nmjcmB2', 'nmlch-pmareB1', 'nmlch-nfmmqA1', 'nmlch-nmjq2', 'nmlch-pmrmmA1', 'nmlch-lfmppB1', 'nmlch-nffh1', 'nfmcp-nmedp1', 'nmlch-pfcmcB2', 'nmlch-nmccc2', 'nmlch-nmjab2', 'nmlch-pmjchB2', 'nmlch-lfmppB2', 'nmlch-nmacm2', 'nmlch-lffhr2', 'nmlch-pmicm2', 'nmlch-nmjcmB1', 'nmlch-nfspB1', 'nmlch-pfsm_1', 'nmlch-nmfhpB1', 'nmlch-nmimp2', 'nmlch-nmjq1', 'nmlch-pfbncA3', 'nmlch-lfsm2', 'nmlch-pfjqm1', 'nmlch-nfmc1', 'nmlch-nfmcpB1', 'nmlch-pfmvmB2', 'nfmcp-nmfc2', 'nmlch-nmjlltB2', 'nmlch-lflql2', 'nmlch-nmfsh2', 'nmlch-pfphnA2', 'nmlch-lmmccB2', 'nfmcp-nmacq2', 'nmlch-nfmp_2', 'nmlch-lmahc1', 'nmlch-nfjn2', 'nmlch-nfvc1', 'nmlch-pmgcqB1', 'nmlch-nfmchB2', 'nmlch-lfrq1', 'nmlch-nmjlltB4', 'nmlch-lmahc2', 'nmlch-pmfrl2', 'nmlch-nmpsa2', 'nmlch-nmjsi2', 'nmlch-lfrll1', 'nmlch-pmgcqA1', 'nmlch-pmlrc2', 'nmlch-nfvc2', 'nmlch-lmfhp1', 'nmlch-nfccpA1', 'nmlch-nmflh1', 'nmlch-pmgcqA2', 'nmlch-nfspA2', 'nmlch-nmdp2', 'nmlch-nmjnn1', 'nmlch-nmpm1', 'mnlch-nfdqqA1', 'nmlch-nmfnn1', 'nmlch-nmjlltB3', 'nmlch-lfrll2', 'nmlch-nmjahA2', 'nmlch-pmjctB1', 'nmlch-pmjctB2', 'nmlch-lffhm1', 'nmlch-lmihr2', 'nmlch-lmmccA1', 'nmlch-lfmcnA2', 'nmlch-nmmbc2', 'nmlch-nmysh1', 'nmlch-lmahr1', 'nmlch-lftccA2', 'nmlch-lfjph2', 'nmlch-nms_l2', 'nmlch-pmdcm2', 'nmlch-nfmcqA1', 'nmlch-nfmqA2', 'nmlch-lfjpl1', 'nmlch-pfmam1', 'nmlch-nmjhq1', 'nmlch-pfamm1', 'nmlch-lffhsB2', 'nmlch-pfa_p1', 'nmlch-nfrn1', 'nmlch-nfjmm1', 'nmlch-nmpsa1', 'nmlch-lfmlq1', 'nmlch-nffhpB2', 'nmlch-pmsccA1', 'nmlch-nmlch', 'nmlch-nffhpA2', 'nmlch-lfchl2', 'nmlch-nfdqqB2', 'nmlch-nmpll2', 'nmlch-nmjll2', 'nmlch-pmmhh2', 'nmlch-nfmam2', 'nmlch-nmfsh1', 'nmlch-pmrmmA2', 'nmlch-nmpll1', 'nmlch-pmjchA1', 'nmlch-nfmchA2', 'nmlch-nfccpA2', 'nfmcp-nmjcp1', 'nmlch-pmacqB2', 'nmlch-pmemh1', 'nmlch-lmjhA2', 'nmlch-pmfm_B2', 'nmlch-nfjms1', 'nmlch-lfmmcB1', 'nmlch-lfmch1', 'nmlch-pmdccA1', 'nmlch-pmdccA2', 'nmlch-nmsca2', 'nmlch-nfoh1', 'nmlch-lmmc1', 'nmlch-pmsccB2', 'nfmcp-nmjcp2', 'nmlch-lmeh2', 'nmlch-pfmvmA1', 'nmlch-nfmchA1', 'nmlch-nfmp_1', 'nmlch- nmjm1', 'nmdch-nmdch', 'nmlch-lmjhB1', 'nmlch-nfipp1', 'nmlch-nfdqqA2', 'nmlch-lmpmc1', 'nmlch-lfmcnB2', 'nmlch-lfjmcB2', 'nmlch-pmjctA2', 'nmlch-lmjaa1', 'nmlch-nmjlltA2', 'nmlch-lmaapB2', 'nmlch-pfcmcA1', 'nmlch-nmflh2', 'nmlch-nmehs2', 'nmlch-pmscmA2', 'nmlch-pfcmcA2', 'nmlch-pmdcm1', 'nmlch-lmjmc2', 'nmlch-pmsccB1', 'nmlch-pmdccB2', 'nmlch-nfrch1', 'nmlch-nmjsi1', 'nmlch-lmjaa2', 'nmlch-nmjhq2', 'nmlch-nfmqA1', 'nmlch-lfmmcB2', 'nmlch-pmscmB1', 'nmlch-lffhsB1', 'nmlch-nfmcB1', 'nmlch-lmahh2', 'nmlch-pmscmA1', 'nmlch-pfmvmB1', 'nmlch-pmsmc1', 'nmlch-nmjlltA1', 'nmlch-nmpm2', 'nmlch-pmscmB2', 'nmlch-pfbnc1', 'nmlch-lfmmcA2', 'nmlch-nfic_2', 'nmlch-lfmch2', 'nmlch-lflch1', 'nmlch-nfmc2', 'nmlch-lfjmcB1', 'nmlch-lfchl1', 'nmlch-nfmmqA2', 'nmlch-lffhsA1', 'nmlch-pmamp2', 'nmlch-pmrmmB2', 'nmlch-lmdc2', 'nmlch-nfmhc2', 'nmlch-nfrn3', 'nmlch-nfmcm1', 'nmlch-lfmlq2', 'nfmcp-nmedp2', 'nmlch-pmacqA2', 'nmlch-nffhpB1', 'nmdch-nflam', 'nmlch-lfrcl1', 'nmlch-nmysh2', 'nmlch-nmjcmA1', 'nmlch-pmemh2', 'nmlch-pmfm_A1', 'nmlch-lflch2', 'nmlch-pmsccA2', 'nmlch-lfjmcA2', 'nmlch-nmjab1', 'nmlch-pmfm_A2', 'nmlch-nmjlltB1', 'nmlch-lmdc1', 'nmlch-nmccc1', 'nmlch-pmacqB1', 'nmlch-pfbncA2', 'nmdch-nfbat1', 'nmlch-nmspa2', 'nmlch-nfrp1', 'nmlch-pmamp1', 'nmlch-nfmm1', 'nmlch-lmaapB1', 'nmlch-nfmlq1', 'nmlch-nfmam1', 'nmlch-pmareA2', 'nmlch-lfmppA2', 'nmlch-pmrmmB1', 'nmlch-nfjml2', 'nmlch-nmjahB1', 'nmlch-lflql1', 'nmlch-lftccA1', 'nmlch-pfmam2', 'nmlch-lfmcnA1', 'nmlch-lfch2', 'nmlch-nmacm1', 'nmlch-lmjhA1', 'nmlch-pmfm_B1', 'nmlch-nmehs1', 'nmlch-nfmcB2', 'nmlch-nfrqm2', 'nmlch-pfphnB1', 'nmlch-lfjhc2', 'nmlch-pfphnA1', 'nmlch-lmihr1', 'nmlch-nmfhpB2', 'nmlch-pmjchB1', 'nmlch-pfphnB2', 'nmlch-nfrchB2', 'nmlch-nfrp2', 'nmlch-lmfhp2', 'nmlch-nmsca1', 'nmlch-lfjph1', 'nmlch-nffhpA1', 'nmlch-nfmcqA2', 'nmlch-nmjahA1', 'nmlch-pfrhf1', 'nmlch-nfrn2', 'nmlch-pm ...

# %%
mapu_limpio1= []
mapu_limpio = []
data = range(len(mapu))
for item in mapu:
    mapu_limpio1 += [re.sub('(\<\*SPA\>)', ' ', item)]
for item in mapu_limpio1:
    mapu_limpio += [remover_puntuacion(item)]
    
resultados = pd.DataFrame(dict(zip(mapu_limpio,espa)),index = data)
