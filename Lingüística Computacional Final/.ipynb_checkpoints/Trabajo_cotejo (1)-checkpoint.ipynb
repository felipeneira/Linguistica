# %% [markdown]
# ### Lectura de los textos

# %%
##preparar texto
##se prepara la lista glob que sirve para trabajar con carpetas
import glob
## se define que lista_files es una lista con los nombres de los archivos 
##los cuales están seleccionados como los txt que se encuentran dentro de primer periodo
lista_files = glob.glob('Entrevistas Hasler/*.txt')
##se define un diccionario donde en los keys se encuentran los nombres y en los values el texto
corpus = {}
##por cada archivo en la lista de archivos
for file in lista_files:
##este se abre con encoding utf-8 y queda definido como file_input
    with open(file, 'r', encoding="utf-8") as file_input:
##se toman los nombres de los textos y se le quitan los primeros 15 caracteres (el nombre de la carpeta)
        corpus[file[35:-4]]=file_input.read()
print('Nombre de los textos')
print(corpus.keys()) 
print('  ')     
print('  ')
# Out:
# Nombre de los textos
# dict_keys(['om] CH.102013.23mins', 'om] CQBM.112012.40mins', 'om] Entrevistas hasler', 'om] GN.1.112013.5mins', 'om] GN.2.112013.40mins', 'om] HM.052013.12mins', 'om] HM.052013.17mins', 'om] HM.052013.18mins', 'om] HM.052013.27mins', 'om] HM.052013.32mins', 'om] HM.102013.30min', 'om] HM.102013.32mins', 'om] HMySM.052013.18mins', 'om] JNyGN.112013.60mins', 'om] TN.012011.45mins'])

# %% [markdown]
# ### Preprocesamiento

# %%
##limpieza texto

import string

numeros= []
for numero in list(range(100)):
    numeros+= [numero]
numeros = str(numeros)
numeros

def remover_puntuacion(s): 
    for c in string.punctuation:
        s=s.replace(c,"")
        s=s.replace('\t','')
    return s
def remover_numeros(k): 
    for z in numeros:
        k=k.replace(z," ")
        k=k.replace('pag','')
    return k

#toma el corpus subido y crea una lista vacía
corpus_misional = []
##por cada uno de los keys en corpus.keys se agrega a corpus_misional el value
for key in corpus.keys():
    corpus_misional += [corpus[key]]     
##por cada una de estas oraciones en 
corpus_preparado = []
for oracion in vacio:
    if oracion.startswith('\\tx '):
        corpus_preparado += [oracion]
        
## se hace un string para poner todos los values de corpus con el objetivo de trabajarlo como un solo texto grande
string_corpus_misional=' '.join(corpus_misional)
        
        
##se le saca la puntuación y se bajan las mayúsculas
string_corpus_contextos = str(corpus_preparado).replace('\n', ' ')
corpus_preparado = str(corpus_preparado).replace('[r]', 'r')
corpus_preparado = str(corpus_preparado).replace('\t', ' ')
corpus_preparado = str(corpus_preparado).replace('R.', ' ')
corpus_preparado = str(corpus_preparado).replace('R,', ' ')
corpus_preparado = str(corpus_preparado).replace('¶', ' ')
corpus_preparado = remover_numeros(str(corpus_preparado))
corpus_preparado = remover_puntuacion(str(corpus_preparado))
corpus_preparado = str(corpus_preparado).lower()
corpus_preparado = str(corpus_preparado).replace('  ', ' ')
corpus_preparado = str(corpus_preparado).replace('\\tx ', ' ')
corpus_preparado = str(corpus_preparado).replace(' tx ', ' ')

lista_corpus_contextos= []
pre_lista_corpus_contextos = str(corpus_preparado).split(' ')
for palabra in pre_lista_corpus_contextos:
    if len(palabra) > 0:
        lista_corpus_contextos += [palabra]

# %%
##luego se usa .split para dividir el texto por \n
string_corpus_misional = string_corpus_misional.split('\n')

##Se define una lista como vacio para poder ingresar cada una de las oraciones del corpus sin espacios en blanco

vacio=[oracion for oracion in string_corpus_misional if len(oracion)>0]

#toma el corpus subido y crea una lista vacía
corpus_misional = []
##por cada uno de los keys en corpus.keys se agrega a corpus_misional el value
for key in corpus.keys():
    corpus_misional += [corpus[key]]

# %%
lista_corpus_contextos
# Out:
# ['ramtueyu',
#  'kiñeke',
#  'pichi',
#  'dungu',
#  'mapudungun',
#  'mew',
#  'fey',
#  '¿chew',
#  'küdawmekeymi',
#  'eymi',
#  'iñche',
#  'ta',
#  'küdawlepun',
#  'ta',
#  'küdawlepun',
#  'ta',
#  'chillan',
#  'chillan',
#  'waria',
#  'mew',
#  'chillan',
#  'waria',
#  'mew',
#  'müley',
#  'ta',
#  'pal',
#  'norte',
#  'piy',
#  'ta',
#  'wingka',
#  'ka',
#  'chummekeymi',
#  'petu',
#  'küdawmen',
#  'ta',
#  'uyew',
#  'dewmameken',
#  'ta',
#  'pichike',
#  'plaza',
#  'anukunuam',
#  'ta',
#  'che',
#  'yawfutuam',
#  'ta',
#  'che',
#  'ka',
#  'nienoam',
#  'ta',
#  'müte',
#  'ta',
#  'trufur',
#  'ta',
#  'ruka',
#  'mew',
#  'konnoam',
#  'ta',
#  'trufur',
#  'cementangey',
#  'ta',
#  'chi',
#  'calle',
#  'anumngealu',
#  'pichike',
#  'matita',
#  'mamüll',
#  'plantayalu',
#  'ta',
#  'chi',
#  'müna',
#  'küme',
#  'dungu',
#  'ka',
#  'chumley',
#  'tüfachi',
#  'küdaw',
#  '¿küme',
#  'küdaw',
#  '¿weda',
#  'küdaw',
#  'küme',
#  'küme',
#  'küdaw',
#  'antü',
#  'müten',
#  'müna',
#  'weda',
#  'müna',
#  'fuertengey',
#  'chi',
#  'antü',
#  'müna',
#  'arengey',
#  'arengey',
#  'müna',
#  'arengey',
#  'uuuuu',
#  'ka',
#  'tüfachi',
#  'küdaw',
#  'mew',
#  'müley',
#  'doy',
#  'mapuche',
#  'che',
#  'wünechi',
#  'mülepukey',
#  'ka',
#  'mapuche',
#  'después',
#  'afachi',
#  'küdaw',
#  'mew',
#  'küpatuyngün',
#  'amutuyngün',
#  'tañi',
#  'ruka',
#  'mew',
#  'amutunge',
#  'amutumun',
#  'deway',
#  'ta',
#  'küdaw',
#  'ta',
#  'ti',
#  'duamwelaiñ',
#  'ta',
#  'che',
#  'piy',
#  'pingekunuy',
#  'ta',
#  'küpatuy',
#  'ya',
#  'afi',
#  'ta',
#  'küdaw',
#  'afi',
#  'ta',
#  'küdaw',
#  'petu',
#  'afi',
#  'ta',
#  'küdaw',
#  'tuntelewelay',
#  'mish',
#  'küdaw',
#  'mew',
#  'eymün',
#  'mapudunguymün',
#  'kiñeke',
#  'mew',
#  'mapuchedungukeiñ',
#  'müna',
#  'küpakimiy',
#  'kiñekentu',
#  'müna',
#  'küpa',
#  'mapuchedunguyngün',
#  'müna',
#  'küme',
#  'dungu',
#  'eymi',
#  'ta',
#  'karpintero',
#  'may',
#  'iñche',
#  'ta',
#  'maetro',
#  'karpintero',
#  'küdawken',
#  'ta',
#  'tabla',
#  'mew',
#  'dewmakeiñ',
#  'moldaje',
#  'ta',
#  'konam',
#  'ta',
#  'cemento',
#  'apoley',
#  'ta',
#  'cemento',
#  'mew',
#  'femngechi',
#  'feychi',
#  'küdaw',
#  'iñchiñ',
#  'ta',
#  'dewmakeiñ',
#  'chumngechi',
#  'kimimi',
#  'tami',
#  'dewman',
#  'karpintero',
#  'reke',
#  'chumngechi',
#  'kimimi',
#  'chumngechi',
#  'adumün',
#  'tüfachi',
#  'küdaw',
#  'adumün',
#  'tüfachi',
#  'küdaw',
#  'kuyfi',
#  'ka',
#  'ayefiiñ',
#  'petu',
#  'pichikalu',
#  'iñche',
#  'ayefiiñ',
#  'tachi',
#  'küdaw',
#  'müna',
#  'küpa',
#  'dewmakefun',
#  'ruka',
#  'despues',
#  'dewman',
#  'ya',
#  're',
#  'adkintun',
#  'müten',
#  're',
#  'adkintun',
#  'müten',
#  'fey',
#  'ka',
#  'pu',
#  'hermano',
#  'iglesia',
#  'mew',
#  'ka',
#  'enseñaenew',
#  'femngechi',
#  'adumün',
#  'eymi',
#  'ayefimi',
#  'tami',
#  'küpan',
#  'iglesia',
#  'mew',
#  'may',
#  'ayefin',
#  'tañi',
#  'miyawael',
#  'iglesia',
#  'mew',
#  'ka',
#  'chumüll',
#  'koni',
#  'ta',
#  'iglesia',
#  'tüfachi',
#  'lof',
#  'mew',
#  'chumüll',
#  'akuy',
#  'may',
#  'mas',
#  'o',
#  'menos',
#  'como',
#  'epu',
#  'mari',
#  'kechu',
#  'tripantü',
#  'mas',
#  'o',
#  'menos',
#  'peno',
#  'amuley',
#  'dew',
#  'tüfachi',
#  'iglesia',
#  'akuy',
#  'ta',
#  'mew',
#  'dewmayngün',
#  'ta',
#  'ngillatuwe',
#  'ruka',
#  'akuy',
#  'ta',
#  'pu',
#  'hermano',
#  'tuwlu',
#  'ta',
#  'pueblo',
#  'mew',
#  'küpaleyngün',
#  'ta',
#  'herramienta',
#  'küdawam',
#  'iñche',
#  'fey',
#  'ka',
#  'nieken',
#  'herramienta',
#  'fey',
#  'ka',
#  'küdawken',
#  'iñche',
#  'chumngechi',
#  'tañi',
#  'katrungeael',
#  'ta',
#  'tabla',
#  'corte',
#  'pingelu',
#  'ka',
#  'müley',
#  'tabla',
#  'rollizo',
#  'chumngechi',
#  'ñi',
#  'katrungeael',
#  'chumngechi',
#  'chew',
#  'püle',
#  'tañi',
#  'elngeael',
#  'chumngechi',
#  'katrungey',
#  'kakelu',
#  'tabla',
#  'famngechi',
#  'katrungey',
#  'madera',
#  'rollizo',
#  'femngechi',
#  'katrungey',
#  'po',
#  'pa',
#  'que',
#  'agarre',
#  'el',
#  'corte',
#  'kom',
#  'adumfin',
#  'feychi',
#  'aaaa',
#  'ta',
#  'yewael',
#  'ta',
#  'chi',
#  'corte',
#  'hermano',
#  'mew',
#  'eymi',
#  'adumimi',
#  'ñi',
#  'küdawael',
#  'karpinteria',
#  'mew',
#  '¿küme',
#  'dungu',
#  'kam',
#  'weda',
#  'dungu',
#  'ñi',
#  'konün',
#  'ta',
#  'hermano',
#  'tüfachi',
#  'lof',
#  'mew',
#  'küme',
#  'dungu',
#  'küme',
#  'dungu',
#  'sino',
#  're',
#  'putun',
#  'dungu',
#  'müleafuy',
#  're',
#  'kewan',
#  'müleafuy',
#  'iglesia',
#  'fey',
#  'permitelay',
#  'feychi',
#  'dungu',
#  'ñi',
#  'putuputunoael',
#  'che',
#  'ruka',
#  'mew',
#  'sino',
#  'katrungey',
#  'tüfachi',
#  'dungu',
#  'ngillangeael',
#  'ta',
#  'zapato',
#  'ngillangeael',
#  'ta',
#  'weshakelu',
#  'ngillangeael',
#  'ta',
#  'iyael',
#  'arreglangeael',
#  'ta',
#  'ruka',
#  'fentren',
#  'dungu',
#  'küme',
#  'kawitu',
#  'mew',
#  'ngutuael',
#  'ngillangeael',
#  'ta',
#  'mueble',
#  'fey',
#  'putukechi',
#  'che',
#  'fey',
#  'feychi',
#  'femngechi',
#  'rakiduam',
#  'nielay',
#  'sino',
#  'ñi',
#  'poyen',
#  'niey',
#  'niey',
#  'plata',
#  'pichiñ',
#  'küpaley',
#  'ta',
#  'pullku',
#  'fentren',
#  'pullku',
#  'küpaley',
#  'ipaymi',
#  'piy',
#  'ta',
#  'wenüy',
#  'putuaiñ',
#  'fiestaiñ',
#  'piy',
#  'fey',
#  'kiñe',
#  'kordero',
#  'ngillayngün',
#  'ñi',
#  'sañchu',
#  'ngillayngün',
#  'fütra',
#  'fiesta',
#  'engün',
#  'fentren',
#  'ayiwün',
#  'nieyngün',
#  'pero',
#  'nielay',
#  'ñi',
#  'ruka',
#  'mew',
#  'domo',
#  'duami',
#  'itrofill',
#  'müleael',
#  'ruka',
#  'mew',
#  'wangku',
#  'mesa',
#  'kom',
#  'fali',
#  'plata',
#  'kom',
#  'plata',
#  'ngillaiñ',
#  'ka',
#  'chi',
#  'pu',
#  'hermano',
#  'akulu',
#  'tüfachi',
#  'lof',
#  'mew',
#  'kellueymew',
#  'ka',
#  'kellupaeiñmew',
#  'kellueiñmew',
#  'weshakelu',
#  'mew',
#  'kimün',
#  'chumngechi',
#  'taiñ',
#  'chumngechi',
#  'tañi',
#  'tañi',
#  'có',
#  'mo',
#  'vivir',
#  'con',
#  'la',
#  'gente',
#  'müna',
#  'küme',
#  'dungu',
#  'fey',
#  'eymi',
#  'ayiwküley',
#  'tami',
#  'piwke',
#  'konlu',
#  'ta',
#  'iglesia',
#  'mew',
#  'may',
#  'ayiwi',
#  'ta',
#  'piwke',
#  'pelon',
#  'reke',
#  'ta',
#  'pelu',
#  'ta',
#  'che',
#  'fey',
#  'eymi',
#  'chem',
#  'dungu',
#  'dewmakeymi',
#  'ta',
#  'iglesia',
#  'mew',
#  'eymi',
#  'chillkatukeymi',
#  'eymi',
#  'ülkantukeymi',
#  'chem',
#  'dungu',
#  'dewmakeymi',
#  'ta',
#  'iglesia',
#  'mew',
#  'iglesia',
#  'mew',
#  'kelluken',
#  'ta',
#  'iñche',
#  'chem',
#  'duam',
#  'mew',
#  'rume',
#  'plata',
#  'mew',
#  'dungun',
#  'tukun',
#  'mew',
#  'femngechi',
#  'apoyar',
#  'al',
#  'encargado',
#  'de',
#  'obra',
#  'piy',
#  'ta',
#  'wingka',
#  'welu',
#  'pepi',
#  'mapudungukeymün',
#  'iglesia',
#  'mew',
#  'may',
#  'mapuchedungukeiñ',
#  'mapuche',
#  'adumafiiñ',
#  'mapuche',
#  'ayekafiiñ',
#  'trawükeiñ',
#  'matetukeiñ',
#  'iglesia',
#  'mew',
#  'müley',
#  'ayekan',
#  'petu',
#  'konnon',
#  'ta',
#  'iglesia',
#  'tüfachi',
#  'lof',
#  'mew',
#  'müley',
#  'ka',
#  'kiñe',
#  'dungu',
#  'si',
#  'po',
#  'kake',
#  'dungu',
#  'müley',
#  'po',
#  'chumley',
#  'ta',
#  'dungu',
#  'petu',
#  'konnon',
#  'ta',
#  'iglesia',
#  'petu',
#  'konnolu',
#  'ta',
#  'iglesia',
#  'ta',
#  'che',
#  'fey',
#  'ta',
#  'niey',
#  'weshake',
#  'rakiduam',
#  'wedwed',
#  'rakiduam',
#  'wenüyafiel',
#  'ta',
#  'pu',
#  'weñefe',
#  'wenüyafiel',
#  'ta',
#  'weshake',
#  'rakiduam',
#  'nielu',
#  'fey',
#  'ti',
#  'chi',
#  'weshake',
#  'rakiduam',
#  'nielu',
#  'chi',
#  'pikunuy',
#  'müten',
#  'iñche',
#  'may',
#  'ta',
#  'ti',
#  'po',
#  'kayñe',
#  'ya',
#  'chumkunuael',
#  'rume',
#  'kulpangeael',
#  'kutrantukunuael',
#  'kutrantuael',
#  'feychi',
#  'dungu',
#  'niey',
#  'fey',
#  'ti',
#  'chi',
#  'nielu',
#  'weshake',
#  'rakiduam',
#  'nielay',
#  'küme',
#  'rakiduam',
#  'po',
#  'kutran',
#  'piwke',
#  'yelay',
#  'ta',
#  'che',
#  'kutran',
#  'piwke',
#  'yelay',
#  'ta',
#  'wentru',
#  'domo',
#  'leli',
#  'tañi',
#  'wedwedkalekafiel',
#  'kulliñ',
#  'peñmafiel',
#  'kulliñ',
#  'weñeñmafiel',
#  'entregayafiel',
#  'fey',
#  'ka',
#  'müten',
#  're',
#  'feychi',
#  'rakiduam',
#  'niey',
#  'ta',
#  'che',
#  'femngechi',
#  'che',
#  'müna',
#  'weda',
#  'dungu',
#  'fey',
#  'santiago',
#  'waria',
#  'mew',
#  'aleko',
#  'feypikeenew',
#  'ta',
#  'ñi',
#  'pu',
#  'awela',
#  'kimelfi',
#  'mapudungun',
#  'fey',
#  'tami',
#  'ñuke',
#  'iney',
#  'pingey',
#  'isabel',
#  'pingefuy',
#  'neculhual',
#  'kimpapeltulafuy',
#  'kimwingkadungulay',
#  'amutuy',
#  'ñi',
#  'kimwingkadungunon',
#  'lay',
#  'perdey',
#  'mapungetuy',
#  'ka',
#  'tami',
#  'ñuke',
#  'kimi',
#  'ta',
#  'kom',
#  'lawen',
#  'kom',
#  'dungu',
#  'lawen',
#  'pichiñ',
#  'kimlafuy',
#  'kim',
#  'lawenlafuy',
#  'tañi',
#  'ñuke',
#  'porque',
#  'femngechi',
#  'dungu',
#  'müley',
#  'mapu',
#  'mew',
#  'kiñekentu',
#  'doy',
#  'kimi',
#  'kiñekentu',
#  'doy',
#  'kimlay',
#  'ka',
#  'kiñekentu',
#  'adumuwkelay',
#  'ka',
#  'müley',
#  'che',
#  'küme',
#  'adumuwlu',
#  'kom',
#  'che',
#  'feley',
#  'domo',
#  'wentru',
#  'kom',
#  'feley',
#  'welu',
#  'tami',
#  'ñuke',
#  'küme',
#  'domo',
#  'müna',
#  'küme',
#  'domo',
#  'siempre',
#  'acordaniekefuy',
#  'tami',
#  'ñuke',
#  'yem',
#  'tuwkefuy',
#  'pingeken',
#  'ka',
#  'che',
#  'kimfiyu',
#  'iñche',
#  'ka',
#  're',
#  'mapudungun',
#  'müten',
#  're',
#  'mapuchedungukefuy',
#  'müten',
#  'de',
#  'repente',
#  'küme',
#  'duamküley',
#  'nütramkakefuy',
#  'pichiken',
#  'itrofill',
#  'dungu',
#  'kuyfi',
#  'chumlekefuel',
#  'ta',
#  'füchake',
#  'che',
#  'nütramkakefuy',
#  'ka',
#  'eymi',
#  'pichikalu',
#  'eymi',
#  're',
#  'mapudunguymi',
#  'müten',
#  'iñche',
#  're',
#  'mapuchedungukefun',
#  'müten',
#  'fey',
#  'ta',
#  'mama',
#  'wingkadungukefunolu',
#  'chumngechi',
#  'kimwingkadunguafun',
#  'ta',
#  'iñche',
#  'ka',
#  'chumngechi',
#  'eymi',
#  'adumimi',
#  'wingkadungun',
#  'wingkadungun',
#  'ta',
#  'adumün',
#  'ta',
#  'escuela',
#  'mew',
#  'escuela',
#  'mew',
#  'konlu',
#  'ta',
#  'iñche',
#  'ka',
#  'despues',
#  'fey',
#  'ka',
#  'dirigentekunungen',
#  'comunidad',
#  'mew',
#  'fey',
#  'femngechi',
#  'viajeyawlu',
#  'pueblo',
#  'mew',
#  'femngechi',
#  'ta',
#  'kimurpun',
#  'tañi',
#  'kimün',
#  'ta',
#  'inawentufin',
#  'ta',
#  'wingka',
#  'inawentufin',
#  'ka',
#  'iñche',
#  'kay',
#  'interesayael',
#  'tañi',
#  'kimael',
#  'doy',
#  'küme',
#  'tañi',
#  'kimael',
#  'ta',
#  'falin',
#  'chengeael',
#  'ta',
#  'welu',
#  'kolekio',
#  'mew',
#  'chumlekefuy',
#  'ta',
#  'kolekio',
#  'pichikalu',
#  'eymi',
#  'weda',
#  'dungu',
#  'küme',
#  'dungu',
#  'mülekefuy',
#  'ta',
#  'colegio',
#  'mew',
#  'may',
#  'chumlekefuy',
#  'kümekefuy',
#  'may',
#  'chumngechi',
#  'kimelkefuy',
#  'ta',
#  'kimelfe',
#  'mülelu',
#  'kolekio',
#  'mew',
#  'feychi',
#  'chi',
#  'pu',
#  'profesor',
#  'wüne',
#  'pu',
#  'profesor',
#  'akulu',
#  'am',
#  'newe',
#  'kimkelafuy',
#  'profesor',
#  'basico',
#  'ngey',
#  'ta',
#  'ti',
#  'chem',
#  'curso',
#  'puwyelu',
#  'engün',
#  'ta',
#  'newe',
#  'kimkelafuy',
#  'lo',
#  'que',
#  'enseñaban',
#  'no',
#  'más',
#  'matemáticas',
#  'y',
#  'copia',
#  'ese',
#  'ka',
#  'müten',
#  'ese',
#  'iñchiñ',
#  'nunca',
#  'pasamos',
#  'en',
#  'ese',
#  'colegio',
#  'yo',
#  'duré',
#  'hasta',
#  'los',
#  'años',
#  'ka',
#  're',
#  'wingkadungun',
#  'müten',
#  'kimelkefuy',
#  'si',
#  'pu',
#  'ñi',
#  'wingkadungual',
#  'ka',
#  'no',
#  'müte',
#  'no',
#  'eran',
#  'exigentes',
#  'en',
#  'eso',
#  'no',
#  'eran',
#  'exigentes',
#  'en',
#  'pero',
#  'kake',
#  'kolekio',
#  'mew',
#  'piam',
#  'ta',
#  'fey',
#  'ta',
#  'pichike',
#  'che',
#  'ta',
#  'mapuchedunguy',
#  'ulelngekefuy',
#  'iñche',
#  'chew',
#  'estudian',
#  'mew',
#  'tañi',
#  'colegio',
#  'femlay',
#  'dungu',
#  'feychi',
#  'kimngelay',
#  'amukeymün',
#  'müten',
#  'amukeiñ',
#  'müten',
#  'puwiñ',
#  'ta',
#  'escuela',
#  'mew',
#  ...]

# %%
##por cada una de estas oraciones en 
corpus_preparado = []
for oracion in vacio:
    if oracion.startswith('\\tx '):
        corpus_preparado += [oracion]

sin_puntos = []
for oracion in corpus_preparado:
    oracion_limpia = remover_puntuacion(oracion)
    sin_puntos += [oracion_limpia.lower()]

##Se toma la lista palabras y luego se ingresan cada una de las palabras de oración que están separadas por comillas
palabras = []
for palabra in lista_corpus_contextos:
    palabras += [palabra]

# %%
palabras
# Out:
# ['ramtueyu',
#  'kiñeke',
#  'pichi',
#  'dungu',
#  'mapudungun',
#  'mew',
#  'fey',
#  '¿chew',
#  'küdawmekeymi',
#  'eymi',
#  'iñche',
#  'ta',
#  'küdawlepun',
#  'ta',
#  'küdawlepun',
#  'ta',
#  'chillan',
#  'chillan',
#  'waria',
#  'mew',
#  'chillan',
#  'waria',
#  'mew',
#  'müley',
#  'ta',
#  'pal',
#  'norte',
#  'piy',
#  'ta',
#  'wingka',
#  'ka',
#  'chummekeymi',
#  'petu',
#  'küdawmen',
#  'ta',
#  'uyew',
#  'dewmameken',
#  'ta',
#  'pichike',
#  'plaza',
#  'anukunuam',
#  'ta',
#  'che',
#  'yawfutuam',
#  'ta',
#  'che',
#  'ka',
#  'nienoam',
#  'ta',
#  'müte',
#  'ta',
#  'trufur',
#  'ta',
#  'ruka',
#  'mew',
#  'konnoam',
#  'ta',
#  'trufur',
#  'cementangey',
#  'ta',
#  'chi',
#  'calle',
#  'anumngealu',
#  'pichike',
#  'matita',
#  'mamüll',
#  'plantayalu',
#  'ta',
#  'chi',
#  'müna',
#  'küme',
#  'dungu',
#  'ka',
#  'chumley',
#  'tüfachi',
#  'küdaw',
#  '¿küme',
#  'küdaw',
#  '¿weda',
#  'küdaw',
#  'küme',
#  'küme',
#  'küdaw',
#  'antü',
#  'müten',
#  'müna',
#  'weda',
#  'müna',
#  'fuertengey',
#  'chi',
#  'antü',
#  'müna',
#  'arengey',
#  'arengey',
#  'müna',
#  'arengey',
#  'uuuuu',
#  'ka',
#  'tüfachi',
#  'küdaw',
#  'mew',
#  'müley',
#  'doy',
#  'mapuche',
#  'che',
#  'wünechi',
#  'mülepukey',
#  'ka',
#  'mapuche',
#  'después',
#  'afachi',
#  'küdaw',
#  'mew',
#  'küpatuyngün',
#  'amutuyngün',
#  'tañi',
#  'ruka',
#  'mew',
#  'amutunge',
#  'amutumun',
#  'deway',
#  'ta',
#  'küdaw',
#  'ta',
#  'ti',
#  'duamwelaiñ',
#  'ta',
#  'che',
#  'piy',
#  'pingekunuy',
#  'ta',
#  'küpatuy',
#  'ya',
#  'afi',
#  'ta',
#  'küdaw',
#  'afi',
#  'ta',
#  'küdaw',
#  'petu',
#  'afi',
#  'ta',
#  'küdaw',
#  'tuntelewelay',
#  'mish',
#  'küdaw',
#  'mew',
#  'eymün',
#  'mapudunguymün',
#  'kiñeke',
#  'mew',
#  'mapuchedungukeiñ',
#  'müna',
#  'küpakimiy',
#  'kiñekentu',
#  'müna',
#  'küpa',
#  'mapuchedunguyngün',
#  'müna',
#  'küme',
#  'dungu',
#  'eymi',
#  'ta',
#  'karpintero',
#  'may',
#  'iñche',
#  'ta',
#  'maetro',
#  'karpintero',
#  'küdawken',
#  'ta',
#  'tabla',
#  'mew',
#  'dewmakeiñ',
#  'moldaje',
#  'ta',
#  'konam',
#  'ta',
#  'cemento',
#  'apoley',
#  'ta',
#  'cemento',
#  'mew',
#  'femngechi',
#  'feychi',
#  'küdaw',
#  'iñchiñ',
#  'ta',
#  'dewmakeiñ',
#  'chumngechi',
#  'kimimi',
#  'tami',
#  'dewman',
#  'karpintero',
#  'reke',
#  'chumngechi',
#  'kimimi',
#  'chumngechi',
#  'adumün',
#  'tüfachi',
#  'küdaw',
#  'adumün',
#  'tüfachi',
#  'küdaw',
#  'kuyfi',
#  'ka',
#  'ayefiiñ',
#  'petu',
#  'pichikalu',
#  'iñche',
#  'ayefiiñ',
#  'tachi',
#  'küdaw',
#  'müna',
#  'küpa',
#  'dewmakefun',
#  'ruka',
#  'despues',
#  'dewman',
#  'ya',
#  're',
#  'adkintun',
#  'müten',
#  're',
#  'adkintun',
#  'müten',
#  'fey',
#  'ka',
#  'pu',
#  'hermano',
#  'iglesia',
#  'mew',
#  'ka',
#  'enseñaenew',
#  'femngechi',
#  'adumün',
#  'eymi',
#  'ayefimi',
#  'tami',
#  'küpan',
#  'iglesia',
#  'mew',
#  'may',
#  'ayefin',
#  'tañi',
#  'miyawael',
#  'iglesia',
#  'mew',
#  'ka',
#  'chumüll',
#  'koni',
#  'ta',
#  'iglesia',
#  'tüfachi',
#  'lof',
#  'mew',
#  'chumüll',
#  'akuy',
#  'may',
#  'mas',
#  'o',
#  'menos',
#  'como',
#  'epu',
#  'mari',
#  'kechu',
#  'tripantü',
#  'mas',
#  'o',
#  'menos',
#  'peno',
#  'amuley',
#  'dew',
#  'tüfachi',
#  'iglesia',
#  'akuy',
#  'ta',
#  'mew',
#  'dewmayngün',
#  'ta',
#  'ngillatuwe',
#  'ruka',
#  'akuy',
#  'ta',
#  'pu',
#  'hermano',
#  'tuwlu',
#  'ta',
#  'pueblo',
#  'mew',
#  'küpaleyngün',
#  'ta',
#  'herramienta',
#  'küdawam',
#  'iñche',
#  'fey',
#  'ka',
#  'nieken',
#  'herramienta',
#  'fey',
#  'ka',
#  'küdawken',
#  'iñche',
#  'chumngechi',
#  'tañi',
#  'katrungeael',
#  'ta',
#  'tabla',
#  'corte',
#  'pingelu',
#  'ka',
#  'müley',
#  'tabla',
#  'rollizo',
#  'chumngechi',
#  'ñi',
#  'katrungeael',
#  'chumngechi',
#  'chew',
#  'püle',
#  'tañi',
#  'elngeael',
#  'chumngechi',
#  'katrungey',
#  'kakelu',
#  'tabla',
#  'famngechi',
#  'katrungey',
#  'madera',
#  'rollizo',
#  'femngechi',
#  'katrungey',
#  'po',
#  'pa',
#  'que',
#  'agarre',
#  'el',
#  'corte',
#  'kom',
#  'adumfin',
#  'feychi',
#  'aaaa',
#  'ta',
#  'yewael',
#  'ta',
#  'chi',
#  'corte',
#  'hermano',
#  'mew',
#  'eymi',
#  'adumimi',
#  'ñi',
#  'küdawael',
#  'karpinteria',
#  'mew',
#  '¿küme',
#  'dungu',
#  'kam',
#  'weda',
#  'dungu',
#  'ñi',
#  'konün',
#  'ta',
#  'hermano',
#  'tüfachi',
#  'lof',
#  'mew',
#  'küme',
#  'dungu',
#  'küme',
#  'dungu',
#  'sino',
#  're',
#  'putun',
#  'dungu',
#  'müleafuy',
#  're',
#  'kewan',
#  'müleafuy',
#  'iglesia',
#  'fey',
#  'permitelay',
#  'feychi',
#  'dungu',
#  'ñi',
#  'putuputunoael',
#  'che',
#  'ruka',
#  'mew',
#  'sino',
#  'katrungey',
#  'tüfachi',
#  'dungu',
#  'ngillangeael',
#  'ta',
#  'zapato',
#  'ngillangeael',
#  'ta',
#  'weshakelu',
#  'ngillangeael',
#  'ta',
#  'iyael',
#  'arreglangeael',
#  'ta',
#  'ruka',
#  'fentren',
#  'dungu',
#  'küme',
#  'kawitu',
#  'mew',
#  'ngutuael',
#  'ngillangeael',
#  'ta',
#  'mueble',
#  'fey',
#  'putukechi',
#  'che',
#  'fey',
#  'feychi',
#  'femngechi',
#  'rakiduam',
#  'nielay',
#  'sino',
#  'ñi',
#  'poyen',
#  'niey',
#  'niey',
#  'plata',
#  'pichiñ',
#  'küpaley',
#  'ta',
#  'pullku',
#  'fentren',
#  'pullku',
#  'küpaley',
#  'ipaymi',
#  'piy',
#  'ta',
#  'wenüy',
#  'putuaiñ',
#  'fiestaiñ',
#  'piy',
#  'fey',
#  'kiñe',
#  'kordero',
#  'ngillayngün',
#  'ñi',
#  'sañchu',
#  'ngillayngün',
#  'fütra',
#  'fiesta',
#  'engün',
#  'fentren',
#  'ayiwün',
#  'nieyngün',
#  'pero',
#  'nielay',
#  'ñi',
#  'ruka',
#  'mew',
#  'domo',
#  'duami',
#  'itrofill',
#  'müleael',
#  'ruka',
#  'mew',
#  'wangku',
#  'mesa',
#  'kom',
#  'fali',
#  'plata',
#  'kom',
#  'plata',
#  'ngillaiñ',
#  'ka',
#  'chi',
#  'pu',
#  'hermano',
#  'akulu',
#  'tüfachi',
#  'lof',
#  'mew',
#  'kellueymew',
#  'ka',
#  'kellupaeiñmew',
#  'kellueiñmew',
#  'weshakelu',
#  'mew',
#  'kimün',
#  'chumngechi',
#  'taiñ',
#  'chumngechi',
#  'tañi',
#  'tañi',
#  'có',
#  'mo',
#  'vivir',
#  'con',
#  'la',
#  'gente',
#  'müna',
#  'küme',
#  'dungu',
#  'fey',
#  'eymi',
#  'ayiwküley',
#  'tami',
#  'piwke',
#  'konlu',
#  'ta',
#  'iglesia',
#  'mew',
#  'may',
#  'ayiwi',
#  'ta',
#  'piwke',
#  'pelon',
#  'reke',
#  'ta',
#  'pelu',
#  'ta',
#  'che',
#  'fey',
#  'eymi',
#  'chem',
#  'dungu',
#  'dewmakeymi',
#  'ta',
#  'iglesia',
#  'mew',
#  'eymi',
#  'chillkatukeymi',
#  'eymi',
#  'ülkantukeymi',
#  'chem',
#  'dungu',
#  'dewmakeymi',
#  'ta',
#  'iglesia',
#  'mew',
#  'iglesia',
#  'mew',
#  'kelluken',
#  'ta',
#  'iñche',
#  'chem',
#  'duam',
#  'mew',
#  'rume',
#  'plata',
#  'mew',
#  'dungun',
#  'tukun',
#  'mew',
#  'femngechi',
#  'apoyar',
#  'al',
#  'encargado',
#  'de',
#  'obra',
#  'piy',
#  'ta',
#  'wingka',
#  'welu',
#  'pepi',
#  'mapudungukeymün',
#  'iglesia',
#  'mew',
#  'may',
#  'mapuchedungukeiñ',
#  'mapuche',
#  'adumafiiñ',
#  'mapuche',
#  'ayekafiiñ',
#  'trawükeiñ',
#  'matetukeiñ',
#  'iglesia',
#  'mew',
#  'müley',
#  'ayekan',
#  'petu',
#  'konnon',
#  'ta',
#  'iglesia',
#  'tüfachi',
#  'lof',
#  'mew',
#  'müley',
#  'ka',
#  'kiñe',
#  'dungu',
#  'si',
#  'po',
#  'kake',
#  'dungu',
#  'müley',
#  'po',
#  'chumley',
#  'ta',
#  'dungu',
#  'petu',
#  'konnon',
#  'ta',
#  'iglesia',
#  'petu',
#  'konnolu',
#  'ta',
#  'iglesia',
#  'ta',
#  'che',
#  'fey',
#  'ta',
#  'niey',
#  'weshake',
#  'rakiduam',
#  'wedwed',
#  'rakiduam',
#  'wenüyafiel',
#  'ta',
#  'pu',
#  'weñefe',
#  'wenüyafiel',
#  'ta',
#  'weshake',
#  'rakiduam',
#  'nielu',
#  'fey',
#  'ti',
#  'chi',
#  'weshake',
#  'rakiduam',
#  'nielu',
#  'chi',
#  'pikunuy',
#  'müten',
#  'iñche',
#  'may',
#  'ta',
#  'ti',
#  'po',
#  'kayñe',
#  'ya',
#  'chumkunuael',
#  'rume',
#  'kulpangeael',
#  'kutrantukunuael',
#  'kutrantuael',
#  'feychi',
#  'dungu',
#  'niey',
#  'fey',
#  'ti',
#  'chi',
#  'nielu',
#  'weshake',
#  'rakiduam',
#  'nielay',
#  'küme',
#  'rakiduam',
#  'po',
#  'kutran',
#  'piwke',
#  'yelay',
#  'ta',
#  'che',
#  'kutran',
#  'piwke',
#  'yelay',
#  'ta',
#  'wentru',
#  'domo',
#  'leli',
#  'tañi',
#  'wedwedkalekafiel',
#  'kulliñ',
#  'peñmafiel',
#  'kulliñ',
#  'weñeñmafiel',
#  'entregayafiel',
#  'fey',
#  'ka',
#  'müten',
#  're',
#  'feychi',
#  'rakiduam',
#  'niey',
#  'ta',
#  'che',
#  'femngechi',
#  'che',
#  'müna',
#  'weda',
#  'dungu',
#  'fey',
#  'santiago',
#  'waria',
#  'mew',
#  'aleko',
#  'feypikeenew',
#  'ta',
#  'ñi',
#  'pu',
#  'awela',
#  'kimelfi',
#  'mapudungun',
#  'fey',
#  'tami',
#  'ñuke',
#  'iney',
#  'pingey',
#  'isabel',
#  'pingefuy',
#  'neculhual',
#  'kimpapeltulafuy',
#  'kimwingkadungulay',
#  'amutuy',
#  'ñi',
#  'kimwingkadungunon',
#  'lay',
#  'perdey',
#  'mapungetuy',
#  'ka',
#  'tami',
#  'ñuke',
#  'kimi',
#  'ta',
#  'kom',
#  'lawen',
#  'kom',
#  'dungu',
#  'lawen',
#  'pichiñ',
#  'kimlafuy',
#  'kim',
#  'lawenlafuy',
#  'tañi',
#  'ñuke',
#  'porque',
#  'femngechi',
#  'dungu',
#  'müley',
#  'mapu',
#  'mew',
#  'kiñekentu',
#  'doy',
#  'kimi',
#  'kiñekentu',
#  'doy',
#  'kimlay',
#  'ka',
#  'kiñekentu',
#  'adumuwkelay',
#  'ka',
#  'müley',
#  'che',
#  'küme',
#  'adumuwlu',
#  'kom',
#  'che',
#  'feley',
#  'domo',
#  'wentru',
#  'kom',
#  'feley',
#  'welu',
#  'tami',
#  'ñuke',
#  'küme',
#  'domo',
#  'müna',
#  'küme',
#  'domo',
#  'siempre',
#  'acordaniekefuy',
#  'tami',
#  'ñuke',
#  'yem',
#  'tuwkefuy',
#  'pingeken',
#  'ka',
#  'che',
#  'kimfiyu',
#  'iñche',
#  'ka',
#  're',
#  'mapudungun',
#  'müten',
#  're',
#  'mapuchedungukefuy',
#  'müten',
#  'de',
#  'repente',
#  'küme',
#  'duamküley',
#  'nütramkakefuy',
#  'pichiken',
#  'itrofill',
#  'dungu',
#  'kuyfi',
#  'chumlekefuel',
#  'ta',
#  'füchake',
#  'che',
#  'nütramkakefuy',
#  'ka',
#  'eymi',
#  'pichikalu',
#  'eymi',
#  're',
#  'mapudunguymi',
#  'müten',
#  'iñche',
#  're',
#  'mapuchedungukefun',
#  'müten',
#  'fey',
#  'ta',
#  'mama',
#  'wingkadungukefunolu',
#  'chumngechi',
#  'kimwingkadunguafun',
#  'ta',
#  'iñche',
#  'ka',
#  'chumngechi',
#  'eymi',
#  'adumimi',
#  'wingkadungun',
#  'wingkadungun',
#  'ta',
#  'adumün',
#  'ta',
#  'escuela',
#  'mew',
#  'escuela',
#  'mew',
#  'konlu',
#  'ta',
#  'iñche',
#  'ka',
#  'despues',
#  'fey',
#  'ka',
#  'dirigentekunungen',
#  'comunidad',
#  'mew',
#  'fey',
#  'femngechi',
#  'viajeyawlu',
#  'pueblo',
#  'mew',
#  'femngechi',
#  'ta',
#  'kimurpun',
#  'tañi',
#  'kimün',
#  'ta',
#  'inawentufin',
#  'ta',
#  'wingka',
#  'inawentufin',
#  'ka',
#  'iñche',
#  'kay',
#  'interesayael',
#  'tañi',
#  'kimael',
#  'doy',
#  'küme',
#  'tañi',
#  'kimael',
#  'ta',
#  'falin',
#  'chengeael',
#  'ta',
#  'welu',
#  'kolekio',
#  'mew',
#  'chumlekefuy',
#  'ta',
#  'kolekio',
#  'pichikalu',
#  'eymi',
#  'weda',
#  'dungu',
#  'küme',
#  'dungu',
#  'mülekefuy',
#  'ta',
#  'colegio',
#  'mew',
#  'may',
#  'chumlekefuy',
#  'kümekefuy',
#  'may',
#  'chumngechi',
#  'kimelkefuy',
#  'ta',
#  'kimelfe',
#  'mülelu',
#  'kolekio',
#  'mew',
#  'feychi',
#  'chi',
#  'pu',
#  'profesor',
#  'wüne',
#  'pu',
#  'profesor',
#  'akulu',
#  'am',
#  'newe',
#  'kimkelafuy',
#  'profesor',
#  'basico',
#  'ngey',
#  'ta',
#  'ti',
#  'chem',
#  'curso',
#  'puwyelu',
#  'engün',
#  'ta',
#  'newe',
#  'kimkelafuy',
#  'lo',
#  'que',
#  'enseñaban',
#  'no',
#  'más',
#  'matemáticas',
#  'y',
#  'copia',
#  'ese',
#  'ka',
#  'müten',
#  'ese',
#  'iñchiñ',
#  'nunca',
#  'pasamos',
#  'en',
#  'ese',
#  'colegio',
#  'yo',
#  'duré',
#  'hasta',
#  'los',
#  'años',
#  'ka',
#  're',
#  'wingkadungun',
#  'müten',
#  'kimelkefuy',
#  'si',
#  'pu',
#  'ñi',
#  'wingkadungual',
#  'ka',
#  'no',
#  'müte',
#  'no',
#  'eran',
#  'exigentes',
#  'en',
#  'eso',
#  'no',
#  'eran',
#  'exigentes',
#  'en',
#  'pero',
#  'kake',
#  'kolekio',
#  'mew',
#  'piam',
#  'ta',
#  'fey',
#  'ta',
#  'pichike',
#  'che',
#  'ta',
#  'mapuchedunguy',
#  'ulelngekefuy',
#  'iñche',
#  'chew',
#  'estudian',
#  'mew',
#  'tañi',
#  'colegio',
#  'femlay',
#  'dungu',
#  'feychi',
#  'kimngelay',
#  'amukeymün',
#  'müten',
#  'amukeiñ',
#  'müten',
#  'puwiñ',
#  'ta',
#  'escuela',
#  'mew',
#  ...]

# %% [markdown]
# # Oraciones con las palabras de interés

# %%
Yem_oraciones = {'yem':[],'ema':[],'em':[]}

# %%
for oracion in palabras:
    for Y in Yem_oraciones.keys():
        if Y in oracion:
            Yem_oraciones[Y]+=[oracion]

# %%
## contamos el número de yem en las oraciones

Yem_repeticiones = {'yem':[],'ema':[],'em':[]} 

for Y in Yem_oraciones.keys():
    for oracion in Yem_oraciones[Y]:
        n = oracion.count(Y)
        Yem_repeticiones[Y]+=[(oracion,n)]

# %%
## función para detectar k palabras anteriores

def k_anteriores(oracion,Y,k):
    lista_contextos = []
    for i in range(len(oracion)):
        word = oracion[i]
        if word == Y:
            r = k
            for r in range(1,k+1):
                if i-r < 0:
                    r -= 1
            lista_contextos += [oracion[i-r:i]+[Y]]
    return lista_contextos

# %%
Yem_contextos = {'yem':[],'ema':[],'em':[]}

# %%
diccionario_contextos_presentacion = {'yem':[],'ema':[],'em':[]}

# %%
lista_yem_presentacion = k_anteriores(lista_corpus_contextos,'yem',1)
lista_em_presentacion = k_anteriores(lista_corpus_contextos,'em',1)
lista_ema_presentacion = k_anteriores(lista_corpus_contextos,'ema',1)
diccionario_contextos_presentacion['yem'] = lista_yem_presentacion
diccionario_contextos_presentacion['em'] = lista_em_presentacion
diccionario_contextos_presentacion['ema'] = lista_ema_presentacion

# %%
diccionario_contextos_presentacion['yem']
# Out:
# [['ñuke', 'yem'],
#  ['mama', 'yem'],
#  ['che', 'yem'],
#  ['ñuke', 'yem'],
#  ['kuku', 'yem'],
#  ['ñuke', 'yem'],
#  ['che', 'yem'],
#  ['che', 'yem'],
#  ['che', 'yem'],
#  ['che', 'yem'],
#  ['laku', 'yem'],
#  ['weychafe', 'yem'],
#  ['chuchu', 'yem'],
#  ['chuchu', 'yem'],
#  ['ñuke', 'yem'],
#  ['laku', 'yem'],
#  ['chuchu', 'yem'],
#  ['chuchu', 'yem'],
#  ['chuchu', 'yem'],
#  ['ñuke', 'yem'],
#  ['chuchu', 'yem'],
#  ['füchakeche', 'yem'],
#  ['füchakeche', 'yem'],
#  ['chuchu', 'yem'],
#  ['chuchu', 'yem'],
#  ['laku', 'yem'],
#  ['kuyfi', 'yem'],
#  ['laku', 'yem'],
#  ['füchakeche', 'yem'],
#  ['füchakeche', 'yem'],
#  ['chuchu', 'yem'],
#  ['che', 'yem'],
#  ['che', 'yem'],
#  ['püllü', 'yem'],
#  ['chuchu', 'yem'],
#  ['palu', 'yem'],
#  ['ñuke', 'yem'],
#  ['palu', 'yem'],
#  ['chuchu', 'yem'],
#  ['che', 'yem'],
#  ['che', 'yem'],
#  ['chuchu', 'yem'],
#  ['chuchu', 'yem'],
#  ['che', 'yem'],
#  ['laku', 'yem'],
#  ['che', 'yem'],
#  ['che', 'yem'],
#  ['kuku', 'yem'],
#  ['che', 'yem'],
#  ['kuku', 'yem'],
#  ['kimche', 'yem'],
#  ['laku', 'yem'],
#  ['laku', 'yem'],
#  ['agustina', 'yem'],
#  ['che', 'yem'],
#  ['chedküy', 'yem']]

# %%
indices_yem = []
for palabra in range(len(lista_corpus_contextos)):
    if lista_corpus_contextos[palabra] == 'yem':
        indices_yem.append(palabra)
indices_yem
# Out:
# [776,
#  2286,
#  2678,
#  4099,
#  5817,
#  6534,
#  7308,
#  7320,
#  7354,
#  7870,
#  7875,
#  7878,
#  8296,
#  8306,
#  8704,
#  8733,
#  8864,
#  8904,
#  8909,
#  8961,
#  8999,
#  10555,
#  10741,
#  10804,
#  10810,
#  10921,
#  11021,
#  11217,
#  11312,
#  12738,
#  12851,
#  14226,
#  14356,
#  17678,
#  17682,
#  18399,
#  20235,
#  20239,
#  20289,
#  20303,
#  20342,
#  20629,
#  20664,
#  23486,
#  25882,
#  25992,
#  26078,
#  26523,
#  26815,
#  27074,
#  27190,
#  28118,
#  28576,
#  28595,
#  28923,
#  29799]

# %%
indices_em = []
for palabra in range(len(lista_corpus_contextos)):
    if lista_corpus_contextos[palabra] == 'em':
        indices_em.append(palabra)

# %%
indices_ema = []
for palabra in range(len(lista_corpus_contextos)):
    if lista_corpus_contextos[palabra] == 'ema':
        indices_ema.append(palabra)

# %%
Yem_indices = {'yem':[],'ema':[],'em':[]} 

Yem_indices['yem'] = indices_yem
Yem_indices['em'] = indices_em
Yem_indices['ema'] = indices_ema

# %%
diccionario_contextos_presentacion['yem']
# Out:
# [['ñuke', 'yem'],
#  ['mama', 'yem'],
#  ['che', 'yem'],
#  ['ñuke', 'yem'],
#  ['kuku', 'yem'],
#  ['ñuke', 'yem'],
#  ['che', 'yem'],
#  ['che', 'yem'],
#  ['che', 'yem'],
#  ['che', 'yem'],
#  ['laku', 'yem'],
#  ['weychafe', 'yem'],
#  ['chuchu', 'yem'],
#  ['chuchu', 'yem'],
#  ['ñuke', 'yem'],
#  ['laku', 'yem'],
#  ['chuchu', 'yem'],
#  ['chuchu', 'yem'],
#  ['chuchu', 'yem'],
#  ['ñuke', 'yem'],
#  ['chuchu', 'yem'],
#  ['füchakeche', 'yem'],
#  ['füchakeche', 'yem'],
#  ['chuchu', 'yem'],
#  ['chuchu', 'yem'],
#  ['laku', 'yem'],
#  ['kuyfi', 'yem'],
#  ['laku', 'yem'],
#  ['füchakeche', 'yem'],
#  ['füchakeche', 'yem'],
#  ['chuchu', 'yem'],
#  ['che', 'yem'],
#  ['che', 'yem'],
#  ['püllü', 'yem'],
#  ['chuchu', 'yem'],
#  ['palu', 'yem'],
#  ['ñuke', 'yem'],
#  ['palu', 'yem'],
#  ['chuchu', 'yem'],
#  ['che', 'yem'],
#  ['che', 'yem'],
#  ['chuchu', 'yem'],
#  ['chuchu', 'yem'],
#  ['che', 'yem'],
#  ['laku', 'yem'],
#  ['che', 'yem'],
#  ['che', 'yem'],
#  ['kuku', 'yem'],
#  ['che', 'yem'],
#  ['kuku', 'yem'],
#  ['kimche', 'yem'],
#  ['laku', 'yem'],
#  ['laku', 'yem'],
#  ['agustina', 'yem'],
#  ['che', 'yem'],
#  ['chedküy', 'yem']]

# %%
## número de oraciones

Yem_oraciones_num = {Y:len(Yem_oraciones[Y]) for Y in Yem_oraciones.keys()}

# %%
Yem_oraciones_num
# Out:
# {'yem': 54, 'ema': 0, 'em': 25}

# %% [markdown]
# ### Co-ocurrencias

# %%
## Red de co-ocurrencias entre palabras :)
import networkx as nx

def GoW(text_clean):
    
    G=nx.Graph()
    for sentence in text_clean:
        if len(sentence)>1:
            pairs=list(zip(sentence,sentence[1:]))
            for pair in pairs:
                if G.has_edge(pair[0],pair[1])==False:
                    G.add_edge(pair[0],pair[1],weight=1)
                else:
                    x=G[pair[0]][pair[1]]['weight']
                    G[pair[0]][pair[1]]['weight']=x+1
                    
    #Gcc = sorted(nx.connected_components(G), key=len, reverse=True)
    #G0 = G.subgraph(Gcc[0])
    
    return G

# %%
grafos = {}

for Y in diccionario_contextos_presentacion.keys():
    oraciones = diccionario_contextos_presentacion[Y]
    grafos[Y]=GoW(oraciones)

# %%
grafos['yem'].edges(data=True)
# Out:
# EdgeDataView([('ñuke', 'yem', {'weight': 6}), ('yem', 'mama', {'weight': 1}), ('yem', 'che', {'weight': 14}), ('yem', 'kuku', {'weight': 3}), ('yem', 'laku', {'weight': 7}), ('yem', 'weychafe', {'weight': 1}), ('yem', 'chuchu', {'weight': 13}), ('yem', 'füchakeche', {'weight': 4}), ('yem', 'kuyfi', {'weight': 1}), ('yem', 'püllü', {'weight': 1}), ('yem', 'palu', {'weight': 2}), ('yem', 'kimche', {'weight': 1}), ('yem', 'agustina', {'weight': 1}), ('yem', 'chedküy', {'weight': 1})])

# %%
import matplotlib.pyplot as plt

def plotG_centrality(Y,size):
    
    G = grafos[Y]
    #G0 = G.copy()
    #G0.remove_edges_from(nx.selfloop_edges(G0))
    #G = nx.k_core(G0)
    #G = nx.maximum_spanning_tree(G)
    fig, ax = plt.subplots(dpi=800)
    centrality = nx.pagerank(G,weight='weight')
    ordered_centrality = {k: v for k, v in sorted(centrality.items(), key=lambda item: item[1],reverse=True)}
    labels = {i:i for i in G.nodes() if i in list(zip(*list(ordered_centrality.items())[:50]))[0]}
    pos = nx.spring_layout(G)
    nx.draw_networkx_nodes(G, pos, node_size = [size*x for x in list(centrality.values())], node_color='gold',node_shape='o',alpha=0.95, linewidths=0.1) 
    nx.draw_networkx_edges(G, pos, alpha=0.5,width=0.2,edge_color='k')
    nx.draw_networkx_labels(G,pos,labels,alpha=1,font_size=3.,font_color='k',font_family='monospace')
    plt.title('Red {}'.format(Y),fontsize=8)
    plt.savefig('red_{}.jpg'.format(Y), format='jpg', transparent=True, bbox_inches='tight',dpi=800)
    plt.axis('off')
    plt.show()

# %%
for Y in grafos.keys():
    plotG_centrality(Y,250)

# %%
## función para ranquear co-ocurrencias :)

def ranking(palabra,k):
    red = grafos[palabra]
    return list({k: v for k, v in sorted(dict(red[palabra]).items(), key=lambda item: item[1]['weight'],reverse=True)}.keys())[:k]

# %%
## palabras más cercanas a -em en el corpus misional

for Y in grafos.keys():
    print(Y,ranking(Y,10))
# Out:
# yem ['che', 'chuchu', 'laku', 'ñuke', 'füchakeche', 'kuku', 'palu', 'mama', 'weychafe', 'kuyfi']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-76-71059ec83c31> in <module>
#       2
#       3 for Y in grafos.keys():
# ----> 4     print(Y,ranking(Y,10))
#
# <ipython-input-36-b2c45109817a> in ranking(palabra, k)
#       3 def ranking(palabra,k):
#       4     red = grafos[palabra]
# ----> 5     return list({k: v for k, v in sorted(dict(red[palabra]).items(), key=lambda item: item[1]['weight'],reverse=True)}.keys())[:k]
#
# ~\anaconda3\lib\site-packages\networkx\classes\graph.py in __getitem__(self, n)
#     473         AtlasView({1: {}})
#     474         """
# --> 475         return self.adj[n]
#     476
#     477     def add_node(self, node_for_adding, **attr):
#
# ~\anaconda3\lib\site-packages\networkx\classes\coreviews.py in __getitem__(self, name)
#      79
#      80     def __getitem__(self, name):
# ---> 81         return AtlasView(self._atlas[name])
#      82
#      83     def copy(self):
#
# KeyError: 'ema'

# %% [markdown]
# ### Cálculos con el corpus

# %%
##Cuantificación

print('Resultados')
print('  ')  

print('Cantidad de palabras')


tokens = []
for palabra in palabras:
        tokens += [palabra]
print(len(tokens))
print('  ')     


print('Cantidad de palabras únicas')


print(len(set(tokens)))
print('  ')     

print('relación')
    

print(len(set(tokens))/len(tokens))
print('  ')     

#contabilizar yem

Yem = {'yem':0,'ema':0,'em':0} 
for key in Yem.keys():
    Yem[key]=tokens.count(key)

print('Cantidad de yem')
 

print(Yem)
# Out:
# Resultados
#
# Cantidad de palabras
# 31147
#
# Cantidad de palabras únicas
# 5369
#
# relación
# 0.17237615179632068
#
# Cantidad de yem
# {'yem': 56, 'ema': 0, 'em': 26}

# %%
tokens
# Out:
# ['ramtueyu',
#  'kiñeke',
#  'pichi',
#  'dungu',
#  'mapudungun',
#  'mew',
#  'fey',
#  '¿chew',
#  'küdawmekeymi',
#  'eymi',
#  'iñche',
#  'ta',
#  'küdawlepun',
#  'ta',
#  'küdawlepun',
#  'ta',
#  'chillan',
#  'chillan',
#  'waria',
#  'mew',
#  'chillan',
#  'waria',
#  'mew',
#  'müley',
#  'ta',
#  'pal',
#  'norte',
#  'piy',
#  'ta',
#  'wingka',
#  'ka',
#  'chummekeymi',
#  'petu',
#  'küdawmen',
#  'ta',
#  'uyew',
#  'dewmameken',
#  'ta',
#  'pichike',
#  'plaza',
#  'anukunuam',
#  'ta',
#  'che',
#  'yawfutuam',
#  'ta',
#  'che',
#  'ka',
#  'nienoam',
#  'ta',
#  'müte',
#  'ta',
#  'trufur',
#  'ta',
#  'ruka',
#  'mew',
#  'konnoam',
#  'ta',
#  'trufur',
#  'cementangey',
#  'ta',
#  'chi',
#  'calle',
#  'anumngealu',
#  'pichike',
#  'matita',
#  'mamüll',
#  'plantayalu',
#  'ta',
#  'chi',
#  'müna',
#  'küme',
#  'dungu',
#  'ka',
#  'chumley',
#  'tüfachi',
#  'küdaw',
#  '¿küme',
#  'küdaw',
#  '¿weda',
#  'küdaw',
#  'küme',
#  'küme',
#  'küdaw',
#  'antü',
#  'müten',
#  'müna',
#  'weda',
#  'müna',
#  'fuertengey',
#  'chi',
#  'antü',
#  'müna',
#  'arengey',
#  'arengey',
#  'müna',
#  'arengey',
#  'uuuuu',
#  'ka',
#  'tüfachi',
#  'küdaw',
#  'mew',
#  'müley',
#  'doy',
#  'mapuche',
#  'che',
#  'wünechi',
#  'mülepukey',
#  'ka',
#  'mapuche',
#  'después',
#  'afachi',
#  'küdaw',
#  'mew',
#  'küpatuyngün',
#  'amutuyngün',
#  'tañi',
#  'ruka',
#  'mew',
#  'amutunge',
#  'amutumun',
#  'deway',
#  'ta',
#  'küdaw',
#  'ta',
#  'ti',
#  'duamwelaiñ',
#  'ta',
#  'che',
#  'piy',
#  'pingekunuy',
#  'ta',
#  'küpatuy',
#  'ya',
#  'afi',
#  'ta',
#  'küdaw',
#  'afi',
#  'ta',
#  'küdaw',
#  'petu',
#  'afi',
#  'ta',
#  'küdaw',
#  'tuntelewelay',
#  'mish',
#  'küdaw',
#  'mew',
#  'eymün',
#  'mapudunguymün',
#  'kiñeke',
#  'mew',
#  'mapuchedungukeiñ',
#  'müna',
#  'küpakimiy',
#  'kiñekentu',
#  'müna',
#  'küpa',
#  'mapuchedunguyngün',
#  'müna',
#  'küme',
#  'dungu',
#  'eymi',
#  'ta',
#  'karpintero',
#  'may',
#  'iñche',
#  'ta',
#  'maetro',
#  'karpintero',
#  'küdawken',
#  'ta',
#  'tabla',
#  'mew',
#  'dewmakeiñ',
#  'moldaje',
#  'ta',
#  'konam',
#  'ta',
#  'cemento',
#  'apoley',
#  'ta',
#  'cemento',
#  'mew',
#  'femngechi',
#  'feychi',
#  'küdaw',
#  'iñchiñ',
#  'ta',
#  'dewmakeiñ',
#  'chumngechi',
#  'kimimi',
#  'tami',
#  'dewman',
#  'karpintero',
#  'reke',
#  'chumngechi',
#  'kimimi',
#  'chumngechi',
#  'adumün',
#  'tüfachi',
#  'küdaw',
#  'adumün',
#  'tüfachi',
#  'küdaw',
#  'kuyfi',
#  'ka',
#  'ayefiiñ',
#  'petu',
#  'pichikalu',
#  'iñche',
#  'ayefiiñ',
#  'tachi',
#  'küdaw',
#  'müna',
#  'küpa',
#  'dewmakefun',
#  'ruka',
#  'despues',
#  'dewman',
#  'ya',
#  're',
#  'adkintun',
#  'müten',
#  're',
#  'adkintun',
#  'müten',
#  'fey',
#  'ka',
#  'pu',
#  'hermano',
#  'iglesia',
#  'mew',
#  'ka',
#  'enseñaenew',
#  'femngechi',
#  'adumün',
#  'eymi',
#  'ayefimi',
#  'tami',
#  'küpan',
#  'iglesia',
#  'mew',
#  'may',
#  'ayefin',
#  'tañi',
#  'miyawael',
#  'iglesia',
#  'mew',
#  'ka',
#  'chumüll',
#  'koni',
#  'ta',
#  'iglesia',
#  'tüfachi',
#  'lof',
#  'mew',
#  'chumüll',
#  'akuy',
#  'may',
#  'mas',
#  'o',
#  'menos',
#  'como',
#  'epu',
#  'mari',
#  'kechu',
#  'tripantü',
#  'mas',
#  'o',
#  'menos',
#  'peno',
#  'amuley',
#  'dew',
#  'tüfachi',
#  'iglesia',
#  'akuy',
#  'ta',
#  'mew',
#  'dewmayngün',
#  'ta',
#  'ngillatuwe',
#  'ruka',
#  'akuy',
#  'ta',
#  'pu',
#  'hermano',
#  'tuwlu',
#  'ta',
#  'pueblo',
#  'mew',
#  'küpaleyngün',
#  'ta',
#  'herramienta',
#  'küdawam',
#  'iñche',
#  'fey',
#  'ka',
#  'nieken',
#  'herramienta',
#  'fey',
#  'ka',
#  'küdawken',
#  'iñche',
#  'chumngechi',
#  'tañi',
#  'katrungeael',
#  'ta',
#  'tabla',
#  'corte',
#  'pingelu',
#  'ka',
#  'müley',
#  'tabla',
#  'rollizo',
#  'chumngechi',
#  'ñi',
#  'katrungeael',
#  'chumngechi',
#  'chew',
#  'püle',
#  'tañi',
#  'elngeael',
#  'chumngechi',
#  'katrungey',
#  'kakelu',
#  'tabla',
#  'famngechi',
#  'katrungey',
#  'madera',
#  'rollizo',
#  'femngechi',
#  'katrungey',
#  'po',
#  'pa',
#  'que',
#  'agarre',
#  'el',
#  'corte',
#  'kom',
#  'adumfin',
#  'feychi',
#  'aaaa',
#  'ta',
#  'yewael',
#  'ta',
#  'chi',
#  'corte',
#  'hermano',
#  'mew',
#  'eymi',
#  'adumimi',
#  'ñi',
#  'küdawael',
#  'karpinteria',
#  'mew',
#  '¿küme',
#  'dungu',
#  'kam',
#  'weda',
#  'dungu',
#  'ñi',
#  'konün',
#  'ta',
#  'hermano',
#  'tüfachi',
#  'lof',
#  'mew',
#  'küme',
#  'dungu',
#  'küme',
#  'dungu',
#  'sino',
#  're',
#  'putun',
#  'dungu',
#  'müleafuy',
#  're',
#  'kewan',
#  'müleafuy',
#  'iglesia',
#  'fey',
#  'permitelay',
#  'feychi',
#  'dungu',
#  'ñi',
#  'putuputunoael',
#  'che',
#  'ruka',
#  'mew',
#  'sino',
#  'katrungey',
#  'tüfachi',
#  'dungu',
#  'ngillangeael',
#  'ta',
#  'zapato',
#  'ngillangeael',
#  'ta',
#  'weshakelu',
#  'ngillangeael',
#  'ta',
#  'iyael',
#  'arreglangeael',
#  'ta',
#  'ruka',
#  'fentren',
#  'dungu',
#  'küme',
#  'kawitu',
#  'mew',
#  'ngutuael',
#  'ngillangeael',
#  'ta',
#  'mueble',
#  'fey',
#  'putukechi',
#  'che',
#  'fey',
#  'feychi',
#  'femngechi',
#  'rakiduam',
#  'nielay',
#  'sino',
#  'ñi',
#  'poyen',
#  'niey',
#  'niey',
#  'plata',
#  'pichiñ',
#  'küpaley',
#  'ta',
#  'pullku',
#  'fentren',
#  'pullku',
#  'küpaley',
#  'ipaymi',
#  'piy',
#  'ta',
#  'wenüy',
#  'putuaiñ',
#  'fiestaiñ',
#  'piy',
#  'fey',
#  'kiñe',
#  'kordero',
#  'ngillayngün',
#  'ñi',
#  'sañchu',
#  'ngillayngün',
#  'fütra',
#  'fiesta',
#  'engün',
#  'fentren',
#  'ayiwün',
#  'nieyngün',
#  'pero',
#  'nielay',
#  'ñi',
#  'ruka',
#  'mew',
#  'domo',
#  'duami',
#  'itrofill',
#  'müleael',
#  'ruka',
#  'mew',
#  'wangku',
#  'mesa',
#  'kom',
#  'fali',
#  'plata',
#  'kom',
#  'plata',
#  'ngillaiñ',
#  'ka',
#  'chi',
#  'pu',
#  'hermano',
#  'akulu',
#  'tüfachi',
#  'lof',
#  'mew',
#  'kellueymew',
#  'ka',
#  'kellupaeiñmew',
#  'kellueiñmew',
#  'weshakelu',
#  'mew',
#  'kimün',
#  'chumngechi',
#  'taiñ',
#  'chumngechi',
#  'tañi',
#  'tañi',
#  'có',
#  'mo',
#  'vivir',
#  'con',
#  'la',
#  'gente',
#  'müna',
#  'küme',
#  'dungu',
#  'fey',
#  'eymi',
#  'ayiwküley',
#  'tami',
#  'piwke',
#  'konlu',
#  'ta',
#  'iglesia',
#  'mew',
#  'may',
#  'ayiwi',
#  'ta',
#  'piwke',
#  'pelon',
#  'reke',
#  'ta',
#  'pelu',
#  'ta',
#  'che',
#  'fey',
#  'eymi',
#  'chem',
#  'dungu',
#  'dewmakeymi',
#  'ta',
#  'iglesia',
#  'mew',
#  'eymi',
#  'chillkatukeymi',
#  'eymi',
#  'ülkantukeymi',
#  'chem',
#  'dungu',
#  'dewmakeymi',
#  'ta',
#  'iglesia',
#  'mew',
#  'iglesia',
#  'mew',
#  'kelluken',
#  'ta',
#  'iñche',
#  'chem',
#  'duam',
#  'mew',
#  'rume',
#  'plata',
#  'mew',
#  'dungun',
#  'tukun',
#  'mew',
#  'femngechi',
#  'apoyar',
#  'al',
#  'encargado',
#  'de',
#  'obra',
#  'piy',
#  'ta',
#  'wingka',
#  'welu',
#  'pepi',
#  'mapudungukeymün',
#  'iglesia',
#  'mew',
#  'may',
#  'mapuchedungukeiñ',
#  'mapuche',
#  'adumafiiñ',
#  'mapuche',
#  'ayekafiiñ',
#  'trawükeiñ',
#  'matetukeiñ',
#  'iglesia',
#  'mew',
#  'müley',
#  'ayekan',
#  'petu',
#  'konnon',
#  'ta',
#  'iglesia',
#  'tüfachi',
#  'lof',
#  'mew',
#  'müley',
#  'ka',
#  'kiñe',
#  'dungu',
#  'si',
#  'po',
#  'kake',
#  'dungu',
#  'müley',
#  'po',
#  'chumley',
#  'ta',
#  'dungu',
#  'petu',
#  'konnon',
#  'ta',
#  'iglesia',
#  'petu',
#  'konnolu',
#  'ta',
#  'iglesia',
#  'ta',
#  'che',
#  'fey',
#  'ta',
#  'niey',
#  'weshake',
#  'rakiduam',
#  'wedwed',
#  'rakiduam',
#  'wenüyafiel',
#  'ta',
#  'pu',
#  'weñefe',
#  'wenüyafiel',
#  'ta',
#  'weshake',
#  'rakiduam',
#  'nielu',
#  'fey',
#  'ti',
#  'chi',
#  'weshake',
#  'rakiduam',
#  'nielu',
#  'chi',
#  'pikunuy',
#  'müten',
#  'iñche',
#  'may',
#  'ta',
#  'ti',
#  'po',
#  'kayñe',
#  'ya',
#  'chumkunuael',
#  'rume',
#  'kulpangeael',
#  'kutrantukunuael',
#  'kutrantuael',
#  'feychi',
#  'dungu',
#  'niey',
#  'fey',
#  'ti',
#  'chi',
#  'nielu',
#  'weshake',
#  'rakiduam',
#  'nielay',
#  'küme',
#  'rakiduam',
#  'po',
#  'kutran',
#  'piwke',
#  'yelay',
#  'ta',
#  'che',
#  'kutran',
#  'piwke',
#  'yelay',
#  'ta',
#  'wentru',
#  'domo',
#  'leli',
#  'tañi',
#  'wedwedkalekafiel',
#  'kulliñ',
#  'peñmafiel',
#  'kulliñ',
#  'weñeñmafiel',
#  'entregayafiel',
#  'fey',
#  'ka',
#  'müten',
#  're',
#  'feychi',
#  'rakiduam',
#  'niey',
#  'ta',
#  'che',
#  'femngechi',
#  'che',
#  'müna',
#  'weda',
#  'dungu',
#  'fey',
#  'santiago',
#  'waria',
#  'mew',
#  'aleko',
#  'feypikeenew',
#  'ta',
#  'ñi',
#  'pu',
#  'awela',
#  'kimelfi',
#  'mapudungun',
#  'fey',
#  'tami',
#  'ñuke',
#  'iney',
#  'pingey',
#  'isabel',
#  'pingefuy',
#  'neculhual',
#  'kimpapeltulafuy',
#  'kimwingkadungulay',
#  'amutuy',
#  'ñi',
#  'kimwingkadungunon',
#  'lay',
#  'perdey',
#  'mapungetuy',
#  'ka',
#  'tami',
#  'ñuke',
#  'kimi',
#  'ta',
#  'kom',
#  'lawen',
#  'kom',
#  'dungu',
#  'lawen',
#  'pichiñ',
#  'kimlafuy',
#  'kim',
#  'lawenlafuy',
#  'tañi',
#  'ñuke',
#  'porque',
#  'femngechi',
#  'dungu',
#  'müley',
#  'mapu',
#  'mew',
#  'kiñekentu',
#  'doy',
#  'kimi',
#  'kiñekentu',
#  'doy',
#  'kimlay',
#  'ka',
#  'kiñekentu',
#  'adumuwkelay',
#  'ka',
#  'müley',
#  'che',
#  'küme',
#  'adumuwlu',
#  'kom',
#  'che',
#  'feley',
#  'domo',
#  'wentru',
#  'kom',
#  'feley',
#  'welu',
#  'tami',
#  'ñuke',
#  'küme',
#  'domo',
#  'müna',
#  'küme',
#  'domo',
#  'siempre',
#  'acordaniekefuy',
#  'tami',
#  'ñuke',
#  'yem',
#  'tuwkefuy',
#  'pingeken',
#  'ka',
#  'che',
#  'kimfiyu',
#  'iñche',
#  'ka',
#  're',
#  'mapudungun',
#  'müten',
#  're',
#  'mapuchedungukefuy',
#  'müten',
#  'de',
#  'repente',
#  'küme',
#  'duamküley',
#  'nütramkakefuy',
#  'pichiken',
#  'itrofill',
#  'dungu',
#  'kuyfi',
#  'chumlekefuel',
#  'ta',
#  'füchake',
#  'che',
#  'nütramkakefuy',
#  'ka',
#  'eymi',
#  'pichikalu',
#  'eymi',
#  're',
#  'mapudunguymi',
#  'müten',
#  'iñche',
#  're',
#  'mapuchedungukefun',
#  'müten',
#  'fey',
#  'ta',
#  'mama',
#  'wingkadungukefunolu',
#  'chumngechi',
#  'kimwingkadunguafun',
#  'ta',
#  'iñche',
#  'ka',
#  'chumngechi',
#  'eymi',
#  'adumimi',
#  'wingkadungun',
#  'wingkadungun',
#  'ta',
#  'adumün',
#  'ta',
#  'escuela',
#  'mew',
#  'escuela',
#  'mew',
#  'konlu',
#  'ta',
#  'iñche',
#  'ka',
#  'despues',
#  'fey',
#  'ka',
#  'dirigentekunungen',
#  'comunidad',
#  'mew',
#  'fey',
#  'femngechi',
#  'viajeyawlu',
#  'pueblo',
#  'mew',
#  'femngechi',
#  'ta',
#  'kimurpun',
#  'tañi',
#  'kimün',
#  'ta',
#  'inawentufin',
#  'ta',
#  'wingka',
#  'inawentufin',
#  'ka',
#  'iñche',
#  'kay',
#  'interesayael',
#  'tañi',
#  'kimael',
#  'doy',
#  'küme',
#  'tañi',
#  'kimael',
#  'ta',
#  'falin',
#  'chengeael',
#  'ta',
#  'welu',
#  'kolekio',
#  'mew',
#  'chumlekefuy',
#  'ta',
#  'kolekio',
#  'pichikalu',
#  'eymi',
#  'weda',
#  'dungu',
#  'küme',
#  'dungu',
#  'mülekefuy',
#  'ta',
#  'colegio',
#  'mew',
#  'may',
#  'chumlekefuy',
#  'kümekefuy',
#  'may',
#  'chumngechi',
#  'kimelkefuy',
#  'ta',
#  'kimelfe',
#  'mülelu',
#  'kolekio',
#  'mew',
#  'feychi',
#  'chi',
#  'pu',
#  'profesor',
#  'wüne',
#  'pu',
#  'profesor',
#  'akulu',
#  'am',
#  'newe',
#  'kimkelafuy',
#  'profesor',
#  'basico',
#  'ngey',
#  'ta',
#  'ti',
#  'chem',
#  'curso',
#  'puwyelu',
#  'engün',
#  'ta',
#  'newe',
#  'kimkelafuy',
#  'lo',
#  'que',
#  'enseñaban',
#  'no',
#  'más',
#  'matemáticas',
#  'y',
#  'copia',
#  'ese',
#  'ka',
#  'müten',
#  'ese',
#  'iñchiñ',
#  'nunca',
#  'pasamos',
#  'en',
#  'ese',
#  'colegio',
#  'yo',
#  'duré',
#  'hasta',
#  'los',
#  'años',
#  'ka',
#  're',
#  'wingkadungun',
#  'müten',
#  'kimelkefuy',
#  'si',
#  'pu',
#  'ñi',
#  'wingkadungual',
#  'ka',
#  'no',
#  'müte',
#  'no',
#  'eran',
#  'exigentes',
#  'en',
#  'eso',
#  'no',
#  'eran',
#  'exigentes',
#  'en',
#  'pero',
#  'kake',
#  'kolekio',
#  'mew',
#  'piam',
#  'ta',
#  'fey',
#  'ta',
#  'pichike',
#  'che',
#  'ta',
#  'mapuchedunguy',
#  'ulelngekefuy',
#  'iñche',
#  'chew',
#  'estudian',
#  'mew',
#  'tañi',
#  'colegio',
#  'femlay',
#  'dungu',
#  'feychi',
#  'kimngelay',
#  'amukeymün',
#  'müten',
#  'amukeiñ',
#  'müten',
#  'puwiñ',
#  'ta',
#  'escuela',
#  'mew',
#  ...]
