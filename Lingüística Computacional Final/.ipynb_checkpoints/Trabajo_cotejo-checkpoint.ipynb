# %% [markdown]
# ### Lectura de los textos

# %%
##preparar texto
##se prepara la lista glob que sirve para trabajar con carpetas
import glob
## se define que lista_files es una lista con los nombres de los archivos 
##los cuales están seleccionados como los txt que se encuentran dentro de primer periodo
lista_files = glob.glob('Entrevistas Hasler/*.txt')
##se define un diccionario donde en los keys se encuentran los nombres y en los values el texto
corpus = {}
##por cada archivo en la lista de archivos
for file in lista_files:
##este se abre con encoding utf-8 y queda definido como file_input
    with open(file, 'r', encoding="utf-8") as file_input:
##se toman los nombres de los textos y se le quitan los primeros 15 caracteres (el nombre de la carpeta)
        corpus[file[35:-4]]=file_input.read()
print('Nombre de los textos')
print(corpus.keys()) 
print('  ')     
print('  ')
# Out:
# Nombre de los textos
# dict_keys(['om] CH.102013.23mins', 'om] CQBM.112012.40mins', 'om] Entrevistas hasler', 'om] GN.1.112013.5mins', 'om] GN.2.112013.40mins', 'om] HM.052013.12mins', 'om] HM.052013.17mins', 'om] HM.052013.18mins', 'om] HM.052013.27mins', 'om] HM.052013.32mins', 'om] HM.102013.30min', 'om] HM.102013.32mins', 'om] HMySM.052013.18mins', 'om] JNyGN.112013.60mins', 'om] TN.012011.45mins'])

# %% [markdown]
# ### Preprocesamiento

# %%
##limpieza texto

import string

numeros= []
for numero in list(range(100)):
    numeros+= [numero]
numeros = str(numeros)
numeros

def remover_puntuacion(s): 
    for c in string.punctuation:
        s=s.replace(c,"")
        s=s.replace('\t','')
    return s
def remover_numeros(k): 
    for z in numeros:
        k=k.replace(z," ")
        k=k.replace('pag','')
    return k

#toma el corpus subido y crea una lista vacía
corpus_misional = []
##por cada uno de los keys en corpus.keys se agrega a corpus_misional el value
for key in corpus.keys():
    corpus_misional += [corpus[key]]   

        
## se hace un string para poner todos los values de corpus con el objetivo de trabajarlo como un solo texto grande
string_corpus_misional=' '.join(corpus_misional)

##luego se usa .split para dividir el texto por \n
string_corpus_misional = string_corpus_misional.split('\n')

##Se define una lista como vacio para poder ingresar cada una de las oraciones del corpus sin espacios en blanco

vacio=[oracion for oracion in string_corpus_misional if len(oracion)>0]


#toma el corpus subido y crea una lista vacía
corpus_misional = []
##por cada uno de los keys en corpus.keys se agrega a corpus_misional el value
for key in corpus.keys():
    corpus_misional += [corpus[key]]     
##por cada una de estas oraciones en 
corpus_preparado = []
for oracion in vacio:
    if oracion.startswith('\\tx '):
        corpus_preparado += [oracion]

sin_puntos = []
for oracion in corpus_preparado:
    oracion_limpia = remover_puntuacion(oracion)
    sin_puntos += [oracion_limpia.lower()]
    sin_puntos += str(sin_puntos).replace('\\tx ', ' ')
    
##Se toma la lista palabras y luego se ingresan cada una de las palabras de oración que están separadas por comillas
palabras = []
for oracion in sin_puntos:
    palabras += [oracion.split(' ')]

##se le saca la puntuación y se bajan las mayúsculas
string_corpus_contextos = str(corpus_preparado).replace('\n', ' ')
corpus_preparado = str(corpus_preparado).replace('[r]', 'r')
corpus_preparado = str(corpus_preparado).replace('\t', ' ')
corpus_preparado = str(corpus_preparado).replace('R.', ' ')
corpus_preparado = str(corpus_preparado).replace('R,', ' ')
corpus_preparado = str(corpus_preparado).replace('¶', ' ')
corpus_preparado = remover_numeros(str(corpus_preparado))
corpus_preparado = remover_puntuacion(str(corpus_preparado))
corpus_preparado = str(corpus_preparado).lower()
corpus_preparado = str(corpus_preparado).replace('  ', ' ')
corpus_preparado = str(corpus_preparado).replace('\\tx ', ' ')
corpus_preparado = str(corpus_preparado).replace(' tx ', ' ')


lista_corpus_contextos= []
pre_lista_corpus_contextos = str(corpus_preparado).split(' ')
for palabra in pre_lista_corpus_contextos:
    if len(palabra) > 0:
        lista_corpus_contextos += [palabra]

# %%
sin_puntos

# %%
##luego se usa .split para dividir el texto por \n
string_corpus_misional = string_corpus_misional.split('\n')

##Se define una lista como vacio para poder ingresar cada una de las oraciones del corpus sin espacios en blanco

vacio=[oracion for oracion in string_corpus_misional if len(oracion)>0]

#toma el corpus subido y crea una lista vacía
corpus_misional = []
##por cada uno de los keys en corpus.keys se agrega a corpus_misional el value
for key in corpus.keys():
    corpus_misional += [corpus[key]]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-afda053c2472> in <module>
#       1 ##luego se usa .split para dividir el texto por \n
# ----> 2 string_corpus_misional = string_corpus_misional.split('\n')
#       3
#       4 ##Se define una lista como vacio para poder ingresar cada una de las oraciones del corpus sin espacios en blanco
#       5
#
# AttributeError: 'list' object has no attribute 'split'

# %%
palabras
# Out:
# [['', ''],
#  ['', ''],
#  ['r'],
#  ['a'],
#  ['m'],
#  ['t'],
#  ['u'],
#  ['e'],
#  ['y'],
#  ['u'],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['k'],
#  ['i'],
#  ['ñ'],
#  ['e'],
#  ['k'],
#  ['e'],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['p'],
#  ['i'],
#  ['c'],
#  ['h'],
#  ['i'],
#  ['', ''],
#  ['', ''],
#  ['d'],
#  ['u'],
#  ['n'],
#  ['g'],
#  ['u'],
#  ['', ''],
#  ['m'],
#  ['a'],
#  ['p'],
#  ['u'],
#  ['d'],
#  ['u'],
#  ['n'],
#  ['g'],
#  ['u'],
#  ['n'],
#  ['', ''],
#  ['m'],
#  ['e'],
#  ['w'],
#  ['', ''],
#  ['f'],
#  ['e'],
#  ['y'],
#  ['', ''],
#  ['¿'],
#  ['c'],
#  ['h'],
#  ['e'],
#  ['w'],
#  ['', ''],
#  ['k'],
#  ['ü'],
#  ['d'],
#  ['a'],
#  ['w'],
#  ['m'],
#  ['e'],
#  ['k'],
#  ['e'],
#  ['y'],
#  ['m'],
#  ['i'],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['e'],
#  ['y'],
#  ['m'],
#  ['i'],
#  ['', ''],
#  ['i'],
#  ['ñ'],
#  ['c'],
#  ['h'],
#  ['e'],
#  ['', ''],
#  ['t'],
#  ['a'],
#  ['', ''],
#  ['k'],
#  ['ü'],
#  ['d'],
#  ['a'],
#  ['w'],
#  ['l'],
#  ['e'],
#  ['p'],
#  ['u'],
#  ['n'],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['t'],
#  ['a'],
#  ['', ''],
#  ['k'],
#  ['ü'],
#  ['d'],
#  ['a'],
#  ['w'],
#  ['l'],
#  ['e'],
#  ['p'],
#  ['u'],
#  ['n'],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['t'],
#  ['a'],
#  ['', ''],
#  ['c'],
#  ['h'],
#  ['i'],
#  ['l'],
#  ['l'],
#  ['a'],
#  ['n'],
#  ['', ''],
#  ['c'],
#  ['h'],
#  ['i'],
#  ['l'],
#  ['l'],
#  ['a'],
#  ['n'],
#  ['', ''],
#  ['w'],
#  ['a'],
#  ['r'],
#  ['i'],
#  ['a'],
#  ['', ''],
#  ['m'],
#  ['e'],
#  ['w'],
#  ['', ''],
#  ['c'],
#  ['h'],
#  ['i'],
#  ['l'],
#  ['l'],
#  ['a'],
#  ['n'],
#  ['', ''],
#  ['w'],
#  ['a'],
#  ['r'],
#  ['i'],
#  ['a'],
#  ['', ''],
#  ['m'],
#  ['e'],
#  ['w'],
#  ['', ''],
#  ['m'],
#  ['ü'],
#  ['l'],
#  ['e'],
#  ['y'],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['t'],
#  ['a'],
#  ['', ''],
#  ['p'],
#  ['a'],
#  ['l'],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['n'],
#  ['o'],
#  ['r'],
#  ['t'],
#  ['e'],
#  ['', ''],
#  ['', ''],
#  ['p'],
#  ['i'],
#  ['y'],
#  ['', ''],
#  ['t'],
#  ['a'],
#  ['', ''],
#  ['w'],
#  ['i'],
#  ['n'],
#  ['g'],
#  ['k'],
#  ['a'],
#  ['', ''],
#  ['k'],
#  ['a'],
#  ['', ''],
#  ['', ''],
#  ['c'],
#  ['h'],
#  ['u'],
#  ['m'],
#  ['m'],
#  ['e'],
#  ['k'],
#  ['e'],
#  ['y'],
#  ['m'],
#  ['i'],
#  ['', ''],
#  ['p'],
#  ['e'],
#  ['t'],
#  ['u'],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['k'],
#  ['ü'],
#  ['d'],
#  ['a'],
#  ['w'],
#  ['m'],
#  ['e'],
#  ['n'],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['t'],
#  ['a'],
#  ['', ''],
#  ['u'],
#  ['y'],
#  ['e'],
#  ['w'],
#  ['', ''],
#  ['d'],
#  ['e'],
#  ['w'],
#  ['m'],
#  ['a'],
#  ['m'],
#  ['e'],
#  ['k'],
#  ['e'],
#  ['n'],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['t'],
#  ['a'],
#  ['', ''],
#  ['p'],
#  ['i'],
#  ['c'],
#  ['h'],
#  ['i'],
#  ['k'],
#  ['e'],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['p'],
#  ['l'],
#  ['a'],
#  ['z'],
#  ['a'],
#  ['', ''],
#  ['a'],
#  ['n'],
#  ['u'],
#  ['k'],
#  ['u'],
#  ['n'],
#  ['u'],
#  ['a'],
#  ['m'],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['t'],
#  ['a'],
#  ['', ''],
#  ['c'],
#  ['h'],
#  ['e'],
#  ['', ''],
#  ['', ''],
#  ['y'],
#  ['a'],
#  ['w'],
#  ['f'],
#  ['u'],
#  ['t'],
#  ['u'],
#  ['a'],
#  ['m'],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['t'],
#  ['a'],
#  ['', ''],
#  ['c'],
#  ['h'],
#  ['e'],
#  ['', ''],
#  ['k'],
#  ['a'],
#  ['', ''],
#  ['', ''],
#  ['n'],
#  ['i'],
#  ['e'],
#  ['n'],
#  ['o'],
#  ['a'],
#  ['m'],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['t'],
#  ['a'],
#  ['', ''],
#  ['m'],
#  ['ü'],
#  ['t'],
#  ['e'],
#  ['', ''],
#  ['', ''],
#  ['t'],
#  ['a'],
#  ['', ''],
#  ['t'],
#  ['r'],
#  ['u'],
#  ['f'],
#  ['u'],
#  ['r'],
#  ['', ''],
#  ['t'],
#  ['a'],
#  ['', ''],
#  ['r'],
#  ['u'],
#  ['k'],
#  ['a'],
#  ['', ''],
#  ['', ''],
#  ['m'],
#  ['e'],
#  ['w'],
#  ['', ''],
#  ['k'],
#  ['o'],
#  ['n'],
#  ['n'],
#  ['o'],
#  ['a'],
#  ['m'],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['t'],
#  ['a'],
#  ['', ''],
#  ['t'],
#  ['r'],
#  ['u'],
#  ['f'],
#  ['u'],
#  ['r'],
#  ['', ''],
#  ['c'],
#  ['e'],
#  ['m'],
#  ['e'],
#  ['n'],
#  ['t'],
#  ['a'],
#  ['n'],
#  ['g'],
#  ['e'],
#  ['y'],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['t'],
#  ['a'],
#  ['', ''],
#  ['c'],
#  ['h'],
#  ['i'],
#  ['', ''],
#  ['c'],
#  ['a'],
#  ['l'],
#  ['l'],
#  ['e'],
#  ['', ''],
#  ['a'],
#  ['n'],
#  ['u'],
#  ['m'],
#  ['n'],
#  ['g'],
#  ['e'],
#  ['a'],
#  ['l'],
#  ['u'],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['p'],
#  ['i'],
#  ['c'],
#  ['h'],
#  ['i'],
#  ['k'],
#  ['e'],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['m'],
#  ['a'],
#  ['t'],
#  ['i'],
#  ['t'],
#  ['a'],
#  ['', ''],
#  ['m'],
#  ['a'],
#  ['m'],
#  ['ü'],
#  ['l'],
#  ['l'],
#  ['', ''],
#  ['p'],
#  ['l'],
#  ['a'],
#  ['n'],
#  ['t'],
#  ['a'],
#  ['y'],
#  ['a'],
#  ['l'],
#  ['u'],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['t'],
#  ['a'],
#  ['', ''],
#  ['c'],
#  ['h'],
#  ['i'],
#  ['', ''],
#  ['m'],
#  ['ü'],
#  ['n'],
#  ['a'],
#  ['', ''],
#  ['', ''],
#  ['k'],
#  ['ü'],
#  ['m'],
#  ['e'],
#  ['', ''],
#  ['', ''],
#  ['d'],
#  ['u'],
#  ['n'],
#  ['g'],
#  ['u'],
#  ['', ''],
#  ['k'],
#  ['a'],
#  ['', ''],
#  ['', ''],
#  ['c'],
#  ['h'],
#  ['u'],
#  ['m'],
#  ['l'],
#  ['e'],
#  ['y'],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['t'],
#  ['ü'],
#  ['f'],
#  ['a'],
#  ['c'],
#  ['h'],
#  ['i'],
#  ['', ''],
#  ['', ''],
#  ['k'],
#  ['ü'],
#  ['d'],
#  ['a'],
#  ['w'],
#  ['', ''],
#  ['¿'],
#  ['k'],
#  ['ü'],
#  ['m'],
#  ['e'],
#  ['', ''],
#  ['k'],
#  ['ü'],
#  ['d'],
#  ['a'],
#  ['w'],
#  ['', ''],
#  ['¿'],
#  ['w'],
#  ['e'],
#  ['d'],
#  ['a'],
#  ['', ''],
#  ['', ''],
#  ['k'],
#  ['ü'],
#  ['d'],
#  ['a'],
#  ['w'],
#  ['', ''],
#  ['k'],
#  ['ü'],
#  ['m'],
#  ['e'],
#  ['', ''],
#  ['', ''],
#  ['k'],
#  ['ü'],
#  ['m'],
#  ['e'],
#  ['', ''],
#  ['', ''],
#  ['k'],
#  ['ü'],
#  ['d'],
#  ['a'],
#  ['w'],
#  ['', ''],
#  ['a'],
#  ['n'],
#  ['t'],
#  ['ü'],
#  ['', ''],
#  ['m'],
#  ['ü'],
#  ['t'],
#  ['e'],
#  ['n'],
#  ['', ''],
#  ['', ''],
#  ['m'],
#  ['ü'],
#  ['n'],
#  ['a'],
#  ['', ''],
#  ['', ''],
#  ['w'],
#  ['e'],
#  ['d'],
#  ['a'],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['m'],
#  ['ü'],
#  ['n'],
#  ['a'],
#  ['', ''],
#  ['', ''],
#  ['f'],
#  ['u'],
#  ['e'],
#  ['r'],
#  ['t'],
#  ['e'],
#  ['n'],
#  ['g'],
#  ['e'],
#  ['y'],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['c'],
#  ['h'],
#  ['i'],
#  ['', ''],
#  ['a'],
#  ['n'],
#  ['t'],
#  ['ü'],
#  ['', ''],
#  ['m'],
#  ['ü'],
#  ['n'],
#  ['a'],
#  ['', ''],
#  ['', ''],
#  ['a'],
#  ['r'],
#  ['e'],
#  ['n'],
#  ['g'],
#  ['e'],
#  ['y'],
#  ['', ''],
#  ['a'],
#  ['r'],
#  ['e'],
#  ['n'],
#  ['g'],
#  ['e'],
#  ['y'],
#  ['', ''],
#  ['m'],
#  ['ü'],
#  ['n'],
#  ['a'],
#  ['', ''],
#  ['', ''],
#  ['a'],
#  ['r'],
#  ['e'],
#  ['n'],
#  ['g'],
#  ['e'],
#  ['y'],
#  ['', ''],
#  ['u'],
#  ['u'],
#  ['u'],
#  ['u'],
#  ['u'],
#  ['', ''],
#  ['k'],
#  ['a'],
#  ['', ''],
#  ['', ''],
#  ['t'],
#  ['ü'],
#  ['f'],
#  ['a'],
#  ['c'],
#  ['h'],
#  ['i'],
#  ['', ''],
#  ['', ''],
#  ['k'],
#  ['ü'],
#  ['d'],
#  ['a'],
#  ['w'],
#  ['', ''],
#  ['', ''],
#  ['m'],
#  ['e'],
#  ['w'],
#  ['', ''],
#  ['m'],
#  ['ü'],
#  ['l'],
#  ['e'],
#  ['y'],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['d'],
#  ['o'],
#  ['y'],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['m'],
#  ['a'],
#  ['p'],
#  ['u'],
#  ['c'],
#  ['h'],
#  ['e'],
#  ['', ''],
#  ['c'],
#  ['h'],
#  ['e'],
#  ['', ''],
#  ['w'],
#  ['ü'],
#  ['n'],
#  ['e'],
#  ['c'],
#  ['h'],
#  ['i'],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['m'],
#  ['ü'],
#  ['l'],
#  ['e'],
#  ['p'],
#  ['u'],
#  ['k'],
#  ['e'],
#  ['y'],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['k'],
#  ['a'],
#  ['', ''],
#  ['', ''],
#  ['m'],
#  ['a'],
#  ['p'],
#  ['u'],
#  ['c'],
#  ['h'],
#  ['e'],
#  ['', ''],
#  ['d'],
#  ['e'],
#  ['s'],
#  ['p'],
#  ['u'],
#  ['é'],
#  ['s'],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['a'],
#  ['f'],
#  ['a'],
#  ['c'],
#  ['h'],
#  ['i'],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['k'],
#  ['ü'],
#  ['d'],
#  ['a'],
#  ['w'],
#  ['', ''],
#  ['', ''],
#  ['m'],
#  ['e'],
#  ['w'],
#  ['', ''],
#  ['k'],
#  ['ü'],
#  ['p'],
#  ['a'],
#  ['t'],
#  ['u'],
#  ['y'],
#  ['n'],
#  ['g'],
#  ['ü'],
#  ['n'],
#  ['', ''],
#  ['', ''],
#  ['a'],
#  ['m'],
#  ['u'],
#  ['t'],
#  ['u'],
#  ['y'],
#  ['n'],
#  ['g'],
#  ['ü'],
#  ['n'],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['t'],
#  ['a'],
#  ['ñ'],
#  ['i'],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['r'],
#  ['u'],
#  ['k'],
#  ['a'],
#  ['', ''],
#  ['', ''],
#  ['m'],
#  ['e'],
#  ['w'],
#  ['', ''],
#  ['a'],
#  ['m'],
#  ['u'],
#  ['t'],
#  ['u'],
#  ['n'],
#  ['g'],
#  ['e'],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['a'],
#  ['m'],
#  ['u'],
#  ['t'],
#  ['u'],
#  ['m'],
#  ['u'],
#  ['n'],
#  ['', ''],
#  ['d'],
#  ['e'],
#  ['w'],
#  ['a'],
#  ['y'],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['t'],
#  ['a'],
#  ['', ''],
#  ['k'],
#  ['ü'],
#  ['d'],
#  ['a'],
#  ['w'],
#  ['', ''],
#  ['', ''],
#  ['t'],
#  ['a'],
#  ['', ''],
#  ['t'],
#  ['i'],
#  ['', ''],
#  ['d'],
#  ['u'],
#  ['a'],
#  ['m'],
#  ['w'],
#  ['e'],
#  ['l'],
#  ['a'],
#  ['i'],
#  ['ñ'],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ...]

# %%
lista_corpus_contextos
# Out:
# ['ramtueyu',
#  'kiñeke',
#  'pichi',
#  'dungu',
#  'mapudungun',
#  'mew',
#  'fey',
#  '¿chew',
#  'küdawmekeymi',
#  'eymi',
#  'iñche',
#  'ta',
#  'küdawlepun',
#  'ta',
#  'küdawlepun',
#  'ta',
#  'chillan',
#  'chillan',
#  'waria',
#  'mew',
#  'chillan',
#  'waria',
#  'mew',
#  'müley',
#  'ta',
#  'pal',
#  'norte',
#  'piy',
#  'ta',
#  'wingka',
#  'ka',
#  'chummekeymi',
#  'petu',
#  'küdawmen',
#  'ta',
#  'uyew',
#  'dewmameken',
#  'ta',
#  'pichike',
#  'plaza',
#  'anukunuam',
#  'ta',
#  'che',
#  'yawfutuam',
#  'ta',
#  'che',
#  'ka',
#  'nienoam',
#  'ta',
#  'müte',
#  'ta',
#  'trufur',
#  'ta',
#  'ruka',
#  'mew',
#  'konnoam',
#  'ta',
#  'trufur',
#  'cementangey',
#  'ta',
#  'chi',
#  'calle',
#  'anumngealu',
#  'pichike',
#  'matita',
#  'mamüll',
#  'plantayalu',
#  'ta',
#  'chi',
#  'müna',
#  'küme',
#  'dungu',
#  'ka',
#  'chumley',
#  'tüfachi',
#  'küdaw',
#  '¿küme',
#  'küdaw',
#  '¿weda',
#  'küdaw',
#  'küme',
#  'küme',
#  'küdaw',
#  'antü',
#  'müten',
#  'müna',
#  'weda',
#  'müna',
#  'fuertengey',
#  'chi',
#  'antü',
#  'müna',
#  'arengey',
#  'arengey',
#  'müna',
#  'arengey',
#  'uuuuu',
#  'ka',
#  'tüfachi',
#  'küdaw',
#  'mew',
#  'müley',
#  'doy',
#  'mapuche',
#  'che',
#  'wünechi',
#  'mülepukey',
#  'ka',
#  'mapuche',
#  'después',
#  'afachi',
#  'küdaw',
#  'mew',
#  'küpatuyngün',
#  'amutuyngün',
#  'tañi',
#  'ruka',
#  'mew',
#  'amutunge',
#  'amutumun',
#  'deway',
#  'ta',
#  'küdaw',
#  'ta',
#  'ti',
#  'duamwelaiñ',
#  'ta',
#  'che',
#  'piy',
#  'pingekunuy',
#  'ta',
#  'küpatuy',
#  'ya',
#  'afi',
#  'ta',
#  'küdaw',
#  'afi',
#  'ta',
#  'küdaw',
#  'petu',
#  'afi',
#  'ta',
#  'küdaw',
#  'tuntelewelay',
#  'mish',
#  'küdaw',
#  'mew',
#  'eymün',
#  'mapudunguymün',
#  'kiñeke',
#  'mew',
#  'mapuchedungukeiñ',
#  'müna',
#  'küpakimiy',
#  'kiñekentu',
#  'müna',
#  'küpa',
#  'mapuchedunguyngün',
#  'müna',
#  'küme',
#  'dungu',
#  'eymi',
#  'ta',
#  'karpintero',
#  'may',
#  'iñche',
#  'ta',
#  'maetro',
#  'karpintero',
#  'küdawken',
#  'ta',
#  'tabla',
#  'mew',
#  'dewmakeiñ',
#  'moldaje',
#  'ta',
#  'konam',
#  'ta',
#  'cemento',
#  'apoley',
#  'ta',
#  'cemento',
#  'mew',
#  'femngechi',
#  'feychi',
#  'küdaw',
#  'iñchiñ',
#  'ta',
#  'dewmakeiñ',
#  'chumngechi',
#  'kimimi',
#  'tami',
#  'dewman',
#  'karpintero',
#  'reke',
#  'chumngechi',
#  'kimimi',
#  'chumngechi',
#  'adumün',
#  'tüfachi',
#  'küdaw',
#  'adumün',
#  'tüfachi',
#  'küdaw',
#  'kuyfi',
#  'ka',
#  'ayefiiñ',
#  'petu',
#  'pichikalu',
#  'iñche',
#  'ayefiiñ',
#  'tachi',
#  'küdaw',
#  'müna',
#  'küpa',
#  'dewmakefun',
#  'ruka',
#  'despues',
#  'dewman',
#  'ya',
#  're',
#  'adkintun',
#  'müten',
#  're',
#  'adkintun',
#  'müten',
#  'fey',
#  'ka',
#  'pu',
#  'hermano',
#  'iglesia',
#  'mew',
#  'ka',
#  'enseñaenew',
#  'femngechi',
#  'adumün',
#  'eymi',
#  'ayefimi',
#  'tami',
#  'küpan',
#  'iglesia',
#  'mew',
#  'may',
#  'ayefin',
#  'tañi',
#  'miyawael',
#  'iglesia',
#  'mew',
#  'ka',
#  'chumüll',
#  'koni',
#  'ta',
#  'iglesia',
#  'tüfachi',
#  'lof',
#  'mew',
#  'chumüll',
#  'akuy',
#  'may',
#  'mas',
#  'o',
#  'menos',
#  'como',
#  'epu',
#  'mari',
#  'kechu',
#  'tripantü',
#  'mas',
#  'o',
#  'menos',
#  'peno',
#  'amuley',
#  'dew',
#  'tüfachi',
#  'iglesia',
#  'akuy',
#  'ta',
#  'mew',
#  'dewmayngün',
#  'ta',
#  'ngillatuwe',
#  'ruka',
#  'akuy',
#  'ta',
#  'pu',
#  'hermano',
#  'tuwlu',
#  'ta',
#  'pueblo',
#  'mew',
#  'küpaleyngün',
#  'ta',
#  'herramienta',
#  'küdawam',
#  'iñche',
#  'fey',
#  'ka',
#  'nieken',
#  'herramienta',
#  'fey',
#  'ka',
#  'küdawken',
#  'iñche',
#  'chumngechi',
#  'tañi',
#  'katrungeael',
#  'ta',
#  'tabla',
#  'corte',
#  'pingelu',
#  'ka',
#  'müley',
#  'tabla',
#  'rollizo',
#  'chumngechi',
#  'ñi',
#  'katrungeael',
#  'chumngechi',
#  'chew',
#  'püle',
#  'tañi',
#  'elngeael',
#  'chumngechi',
#  'katrungey',
#  'kakelu',
#  'tabla',
#  'famngechi',
#  'katrungey',
#  'madera',
#  'rollizo',
#  'femngechi',
#  'katrungey',
#  'po',
#  'pa',
#  'que',
#  'agarre',
#  'el',
#  'corte',
#  'kom',
#  'adumfin',
#  'feychi',
#  'aaaa',
#  'ta',
#  'yewael',
#  'ta',
#  'chi',
#  'corte',
#  'hermano',
#  'mew',
#  'eymi',
#  'adumimi',
#  'ñi',
#  'küdawael',
#  'karpinteria',
#  'mew',
#  '¿küme',
#  'dungu',
#  'kam',
#  'weda',
#  'dungu',
#  'ñi',
#  'konün',
#  'ta',
#  'hermano',
#  'tüfachi',
#  'lof',
#  'mew',
#  'küme',
#  'dungu',
#  'küme',
#  'dungu',
#  'sino',
#  're',
#  'putun',
#  'dungu',
#  'müleafuy',
#  're',
#  'kewan',
#  'müleafuy',
#  'iglesia',
#  'fey',
#  'permitelay',
#  'feychi',
#  'dungu',
#  'ñi',
#  'putuputunoael',
#  'che',
#  'ruka',
#  'mew',
#  'sino',
#  'katrungey',
#  'tüfachi',
#  'dungu',
#  'ngillangeael',
#  'ta',
#  'zapato',
#  'ngillangeael',
#  'ta',
#  'weshakelu',
#  'ngillangeael',
#  'ta',
#  'iyael',
#  'arreglangeael',
#  'ta',
#  'ruka',
#  'fentren',
#  'dungu',
#  'küme',
#  'kawitu',
#  'mew',
#  'ngutuael',
#  'ngillangeael',
#  'ta',
#  'mueble',
#  'fey',
#  'putukechi',
#  'che',
#  'fey',
#  'feychi',
#  'femngechi',
#  'rakiduam',
#  'nielay',
#  'sino',
#  'ñi',
#  'poyen',
#  'niey',
#  'niey',
#  'plata',
#  'pichiñ',
#  'küpaley',
#  'ta',
#  'pullku',
#  'fentren',
#  'pullku',
#  'küpaley',
#  'ipaymi',
#  'piy',
#  'ta',
#  'wenüy',
#  'putuaiñ',
#  'fiestaiñ',
#  'piy',
#  'fey',
#  'kiñe',
#  'kordero',
#  'ngillayngün',
#  'ñi',
#  'sañchu',
#  'ngillayngün',
#  'fütra',
#  'fiesta',
#  'engün',
#  'fentren',
#  'ayiwün',
#  'nieyngün',
#  'pero',
#  'nielay',
#  'ñi',
#  'ruka',
#  'mew',
#  'domo',
#  'duami',
#  'itrofill',
#  'müleael',
#  'ruka',
#  'mew',
#  'wangku',
#  'mesa',
#  'kom',
#  'fali',
#  'plata',
#  'kom',
#  'plata',
#  'ngillaiñ',
#  'ka',
#  'chi',
#  'pu',
#  'hermano',
#  'akulu',
#  'tüfachi',
#  'lof',
#  'mew',
#  'kellueymew',
#  'ka',
#  'kellupaeiñmew',
#  'kellueiñmew',
#  'weshakelu',
#  'mew',
#  'kimün',
#  'chumngechi',
#  'taiñ',
#  'chumngechi',
#  'tañi',
#  'tañi',
#  'có',
#  'mo',
#  'vivir',
#  'con',
#  'la',
#  'gente',
#  'müna',
#  'küme',
#  'dungu',
#  'fey',
#  'eymi',
#  'ayiwküley',
#  'tami',
#  'piwke',
#  'konlu',
#  'ta',
#  'iglesia',
#  'mew',
#  'may',
#  'ayiwi',
#  'ta',
#  'piwke',
#  'pelon',
#  'reke',
#  'ta',
#  'pelu',
#  'ta',
#  'che',
#  'fey',
#  'eymi',
#  'chem',
#  'dungu',
#  'dewmakeymi',
#  'ta',
#  'iglesia',
#  'mew',
#  'eymi',
#  'chillkatukeymi',
#  'eymi',
#  'ülkantukeymi',
#  'chem',
#  'dungu',
#  'dewmakeymi',
#  'ta',
#  'iglesia',
#  'mew',
#  'iglesia',
#  'mew',
#  'kelluken',
#  'ta',
#  'iñche',
#  'chem',
#  'duam',
#  'mew',
#  'rume',
#  'plata',
#  'mew',
#  'dungun',
#  'tukun',
#  'mew',
#  'femngechi',
#  'apoyar',
#  'al',
#  'encargado',
#  'de',
#  'obra',
#  'piy',
#  'ta',
#  'wingka',
#  'welu',
#  'pepi',
#  'mapudungukeymün',
#  'iglesia',
#  'mew',
#  'may',
#  'mapuchedungukeiñ',
#  'mapuche',
#  'adumafiiñ',
#  'mapuche',
#  'ayekafiiñ',
#  'trawükeiñ',
#  'matetukeiñ',
#  'iglesia',
#  'mew',
#  'müley',
#  'ayekan',
#  'petu',
#  'konnon',
#  'ta',
#  'iglesia',
#  'tüfachi',
#  'lof',
#  'mew',
#  'müley',
#  'ka',
#  'kiñe',
#  'dungu',
#  'si',
#  'po',
#  'kake',
#  'dungu',
#  'müley',
#  'po',
#  'chumley',
#  'ta',
#  'dungu',
#  'petu',
#  'konnon',
#  'ta',
#  'iglesia',
#  'petu',
#  'konnolu',
#  'ta',
#  'iglesia',
#  'ta',
#  'che',
#  'fey',
#  'ta',
#  'niey',
#  'weshake',
#  'rakiduam',
#  'wedwed',
#  'rakiduam',
#  'wenüyafiel',
#  'ta',
#  'pu',
#  'weñefe',
#  'wenüyafiel',
#  'ta',
#  'weshake',
#  'rakiduam',
#  'nielu',
#  'fey',
#  'ti',
#  'chi',
#  'weshake',
#  'rakiduam',
#  'nielu',
#  'chi',
#  'pikunuy',
#  'müten',
#  'iñche',
#  'may',
#  'ta',
#  'ti',
#  'po',
#  'kayñe',
#  'ya',
#  'chumkunuael',
#  'rume',
#  'kulpangeael',
#  'kutrantukunuael',
#  'kutrantuael',
#  'feychi',
#  'dungu',
#  'niey',
#  'fey',
#  'ti',
#  'chi',
#  'nielu',
#  'weshake',
#  'rakiduam',
#  'nielay',
#  'küme',
#  'rakiduam',
#  'po',
#  'kutran',
#  'piwke',
#  'yelay',
#  'ta',
#  'che',
#  'kutran',
#  'piwke',
#  'yelay',
#  'ta',
#  'wentru',
#  'domo',
#  'leli',
#  'tañi',
#  'wedwedkalekafiel',
#  'kulliñ',
#  'peñmafiel',
#  'kulliñ',
#  'weñeñmafiel',
#  'entregayafiel',
#  'fey',
#  'ka',
#  'müten',
#  're',
#  'feychi',
#  'rakiduam',
#  'niey',
#  'ta',
#  'che',
#  'femngechi',
#  'che',
#  'müna',
#  'weda',
#  'dungu',
#  'fey',
#  'santiago',
#  'waria',
#  'mew',
#  'aleko',
#  'feypikeenew',
#  'ta',
#  'ñi',
#  'pu',
#  'awela',
#  'kimelfi',
#  'mapudungun',
#  'fey',
#  'tami',
#  'ñuke',
#  'iney',
#  'pingey',
#  'isabel',
#  'pingefuy',
#  'neculhual',
#  'kimpapeltulafuy',
#  'kimwingkadungulay',
#  'amutuy',
#  'ñi',
#  'kimwingkadungunon',
#  'lay',
#  'perdey',
#  'mapungetuy',
#  'ka',
#  'tami',
#  'ñuke',
#  'kimi',
#  'ta',
#  'kom',
#  'lawen',
#  'kom',
#  'dungu',
#  'lawen',
#  'pichiñ',
#  'kimlafuy',
#  'kim',
#  'lawenlafuy',
#  'tañi',
#  'ñuke',
#  'porque',
#  'femngechi',
#  'dungu',
#  'müley',
#  'mapu',
#  'mew',
#  'kiñekentu',
#  'doy',
#  'kimi',
#  'kiñekentu',
#  'doy',
#  'kimlay',
#  'ka',
#  'kiñekentu',
#  'adumuwkelay',
#  'ka',
#  'müley',
#  'che',
#  'küme',
#  'adumuwlu',
#  'kom',
#  'che',
#  'feley',
#  'domo',
#  'wentru',
#  'kom',
#  'feley',
#  'welu',
#  'tami',
#  'ñuke',
#  'küme',
#  'domo',
#  'müna',
#  'küme',
#  'domo',
#  'siempre',
#  'acordaniekefuy',
#  'tami',
#  'ñuke',
#  'yem',
#  'tuwkefuy',
#  'pingeken',
#  'ka',
#  'che',
#  'kimfiyu',
#  'iñche',
#  'ka',
#  're',
#  'mapudungun',
#  'müten',
#  're',
#  'mapuchedungukefuy',
#  'müten',
#  'de',
#  'repente',
#  'küme',
#  'duamküley',
#  'nütramkakefuy',
#  'pichiken',
#  'itrofill',
#  'dungu',
#  'kuyfi',
#  'chumlekefuel',
#  'ta',
#  'füchake',
#  'che',
#  'nütramkakefuy',
#  'ka',
#  'eymi',
#  'pichikalu',
#  'eymi',
#  're',
#  'mapudunguymi',
#  'müten',
#  'iñche',
#  're',
#  'mapuchedungukefun',
#  'müten',
#  'fey',
#  'ta',
#  'mama',
#  'wingkadungukefunolu',
#  'chumngechi',
#  'kimwingkadunguafun',
#  'ta',
#  'iñche',
#  'ka',
#  'chumngechi',
#  'eymi',
#  'adumimi',
#  'wingkadungun',
#  'wingkadungun',
#  'ta',
#  'adumün',
#  'ta',
#  'escuela',
#  'mew',
#  'escuela',
#  'mew',
#  'konlu',
#  'ta',
#  'iñche',
#  'ka',
#  'despues',
#  'fey',
#  'ka',
#  'dirigentekunungen',
#  'comunidad',
#  'mew',
#  'fey',
#  'femngechi',
#  'viajeyawlu',
#  'pueblo',
#  'mew',
#  'femngechi',
#  'ta',
#  'kimurpun',
#  'tañi',
#  'kimün',
#  'ta',
#  'inawentufin',
#  'ta',
#  'wingka',
#  'inawentufin',
#  'ka',
#  'iñche',
#  'kay',
#  'interesayael',
#  'tañi',
#  'kimael',
#  'doy',
#  'küme',
#  'tañi',
#  'kimael',
#  'ta',
#  'falin',
#  'chengeael',
#  'ta',
#  'welu',
#  'kolekio',
#  'mew',
#  'chumlekefuy',
#  'ta',
#  'kolekio',
#  'pichikalu',
#  'eymi',
#  'weda',
#  'dungu',
#  'küme',
#  'dungu',
#  'mülekefuy',
#  'ta',
#  'colegio',
#  'mew',
#  'may',
#  'chumlekefuy',
#  'kümekefuy',
#  'may',
#  'chumngechi',
#  'kimelkefuy',
#  'ta',
#  'kimelfe',
#  'mülelu',
#  'kolekio',
#  'mew',
#  'feychi',
#  'chi',
#  'pu',
#  'profesor',
#  'wüne',
#  'pu',
#  'profesor',
#  'akulu',
#  'am',
#  'newe',
#  'kimkelafuy',
#  'profesor',
#  'basico',
#  'ngey',
#  'ta',
#  'ti',
#  'chem',
#  'curso',
#  'puwyelu',
#  'engün',
#  'ta',
#  'newe',
#  'kimkelafuy',
#  'lo',
#  'que',
#  'enseñaban',
#  'no',
#  'más',
#  'matemáticas',
#  'y',
#  'copia',
#  'ese',
#  'ka',
#  'müten',
#  'ese',
#  'iñchiñ',
#  'nunca',
#  'pasamos',
#  'en',
#  'ese',
#  'colegio',
#  'yo',
#  'duré',
#  'hasta',
#  'los',
#  'años',
#  'ka',
#  're',
#  'wingkadungun',
#  'müten',
#  'kimelkefuy',
#  'si',
#  'pu',
#  'ñi',
#  'wingkadungual',
#  'ka',
#  'no',
#  'müte',
#  'no',
#  'eran',
#  'exigentes',
#  'en',
#  'eso',
#  'no',
#  'eran',
#  'exigentes',
#  'en',
#  'pero',
#  'kake',
#  'kolekio',
#  'mew',
#  'piam',
#  'ta',
#  'fey',
#  'ta',
#  'pichike',
#  'che',
#  'ta',
#  'mapuchedunguy',
#  'ulelngekefuy',
#  'iñche',
#  'chew',
#  'estudian',
#  'mew',
#  'tañi',
#  'colegio',
#  'femlay',
#  'dungu',
#  'feychi',
#  'kimngelay',
#  'amukeymün',
#  'müten',
#  'amukeiñ',
#  'müten',
#  'puwiñ',
#  'ta',
#  'escuela',
#  'mew',
#  ...]

# %% [markdown]
# # Oraciones con las palabras de interés

# %%
Yem_oraciones = {'yem':[],'ema':[],'em':[]}

# %%
for oracion in palabras:
    for Y in Yem_oraciones.keys():
        if Y in oracion:
            Yem_oraciones[Y]+=[oracion]

# %%
## contamos el número de yem en las oraciones

Yem_repeticiones = {'yem':[],'ema':[],'em':[]} 

for Y in Yem_oraciones.keys():
    for oracion in Yem_oraciones[Y]:
        n = oracion.count(Y)
        Yem_repeticiones[Y]+=[(oracion,n)]

# %%
## función para detectar k palabras anteriores

def k_anteriores(oracion,Y,k):
    lista_contextos = []
    for i in range(len(oracion)):
        word = oracion[i]
        if word == Y:
            r = k
            for r in range(1,k+1):
                if i-r < 0:
                    r -= 1
            lista_contextos += [oracion[i-r:i]+[Y]]
    return lista_contextos

# %%
Yem_contextos = {'yem':[],'ema':[],'em':[]}

# %%
diccionario_contextos_presentacion = {'yem':[],'ema':[],'em':[]}

# %%
lista_yem_presentacion = k_anteriores(lista_corpus_contextos,'yem',5)
lista_em_presentacion = k_anteriores(lista_corpus_contextos,'em',5)
lista_ema_presentacion = k_anteriores(lista_corpus_contextos,'ema',5)
diccionario_contextos_presentacion['yem'] = lista_yem_presentacion
diccionario_contextos_presentacion['em'] = lista_em_presentacion
diccionario_contextos_presentacion['ema'] = lista_ema_presentacion

# %%
diccionario_contextos_presentacion['yem']
# Out:
# [['domo', 'siempre', 'acordaniekefuy', 'tami', 'ñuke', 'yem'],
#  ['kimniey', 'decia', 'pikefuy', 'ñi', 'mama', 'yem'],
#  ['kimülkantulu', 'may', 'pütrülekefuy', 'füchake', 'che', 'yem'],
#  ['kazi', 'tranakununge', 'piy', 'ñi', 'ñuke', 'yem'],
#  ['iñchiñ', 'pu', 'ñi', 'kuse', 'kuku', 'yem'],
#  ['fam', 'entuniengekey', 'pikefuy', 'ñi', 'ñuke', 'yem'],
#  ['pellkelekepelay', 'engün', 'taiñ', 'füchake', 'che', 'yem'],
#  ['mapuchengen', 'pellkelepelayngün', 'taiñ', 'füchake', 'che', 'yem'],
#  ['feymew', 'pellkeley', 'ta', 'füchake', 'che', 'yem'],
#  ['feyngerkey', 'ta', 'ñi', 'füchake', 'che', 'yem'],
#  ['yem', 'ta', 'ñi', 'füchake', 'laku', 'yem'],
#  ['füchake', 'laku', 'yem', 'füchake', 'weychafe', 'yem'],
#  ['ñi', 'amutun', 'tañi', 'kuse', 'chuchu', 'yem'],
#  ['ülkantun', 'elelenew', 'tañi', 'kuse', 'chuchu', 'yem'],
#  ['ta', 'epeke', 'amutuy', 'tañi', 'ñuke', 'yem'],
#  ['wenüy', 'fey', 'tañi', 'tañi', 'laku', 'yem'],
#  ['rupalu', 'iñche', 'triparumey', 'tañi', 'chuchu', 'yem'],
#  ['tañi', 'layael', 'tañi', 'kuse', 'chuchu', 'yem'],
#  ['yem', 'amutuael', 'tañi', 'kuse', 'chuchu', 'yem'],
#  ['mew', 'feychi', 'layalu', 'ñi', 'ñuke', 'yem'],
#  ['amutual', 'tañi', 'kuse', 'kuse', 'chuchu', 'yem'],
#  ['ta', 'mapuche', 'kimpalu', 'ñi', 'füchakeche', 'yem'],
#  ['eleletew', 'feychi', 'kimün', 'tañi', 'füchakeche', 'yem'],
#  ['wimun', 'tati', 'ka', 'tami', 'chuchu', 'yem'],
#  ['¿ülkantukefuy', 'ka', 'tañi', 'ruf', 'chuchu', 'yem'],
#  ['tripape', 'femngechi', 'ülkantukefuy', 'tañi', 'laku', 'yem'],
#  ['ta', 'dewmangekey', 'ta', 'uyew', 'kuyfi', 'yem'],
#  ['pichikalu', 'iñche', 'iñche', 'tañi', 'laku', 'yem'],
#  ['tüfachi', 'ülkantun', 'ülkantukelafuy', 'tañi', 'füchakeche', 'yem'],
#  ['ta', 'mapu', 'pikey', 'tañi', 'füchakeche', 'yem'],
#  ['pikefuy', 'ta', 'ti', 'kuse', 'chuchu', 'yem'],
#  ['küdawael', 'iñchiñ', 'taiñ', 'füchake', 'che', 'yem'],
#  ['nütramkakefiel', 'feyngey', 'tañi', 'füchake', 'che', 'yem'],
#  ['epe', 'amutuael', 'tañi', 'kuse', 'püllü', 'yem'],
#  ['püllü', 'yem', 'tañi', 'kuse', 'chuchu', 'yem'],
#  ['ta', 'feychi', 'mongen', 'tañi', 'palu', 'yem'],
#  ['müley', 'fendemekefuy', 'tañi', 'kuse', 'ñuke', 'yem'],
#  ['ñuke', 'yem', 'tañi', 'kuse', 'palu', 'yem'],
#  ['mew', 'pikefuy', 'tañi', 'kuse', 'chuchu', 'yem'],
#  ['femngechi', 'weñengekefuy', 'ta', 'füchake', 'che', 'yem'],
#  ['femngechi', 'weñeñmangekefuy', 'tañi', 'füchake', 'che', 'yem'],
#  ['feychi', 'feypikefuenew', 'tañi', 'kuse', 'chuchu', 'yem'],
#  ['mapu', 'pifin', 'feymew', 'tami', 'chuchu', 'yem'],
#  ['mongen', 'pikefuy', 'ta', 'kuyfike', 'che', 'yem'],
#  ['mew', 'iñche', 'ñi', 'fücha', 'laku', 'yem'],
#  ['falingetukefuy', 'ta', 'ngülam', 'füchake', 'che', 'yem'],
#  ['lalu', 'am', 'taiñ', 'füchake', 'che', 'yem'],
#  ['ngekelafuy', 'iñche', 'ñi', 'kushe', 'kuku', 'yem'],
#  ['rume', 'kimfuy', 'ta', 'kuyfike', 'che', 'yem'],
#  ['apoley', 'küyen', 'mew', 'ñi', 'kuku', 'yem'],
#  ['kuyfi', 'am', 'mülelu', 'doy', 'kimche', 'yem'],
#  ['dewmakelefuy', 'ta', 'ñi', 'kuse', 'laku', 'yem'],
#  ['allküñmakefuy', 'ta', 'ñi', 'kuse', 'laku', 'yem'],
#  ['ñi', 'ñuke', 'ka', 'lawentuchefengey', 'agustina', 'yem'],
#  ['ka', 'kom', 'kimniekey', 'kusheke', 'che', 'yem'],
#  ['mew', 'engu', 'chedküywen', 'anay', 'chedküy', 'yem']]

# %%
indices_yem = []
for palabra in range(len(lista_corpus_contextos)):
    if lista_corpus_contextos[palabra] == 'yem':
        indices_yem.append(palabra)
indices_yem
# Out:
# [776,
#  2286,
#  2678,
#  4099,
#  5817,
#  6534,
#  7308,
#  7320,
#  7354,
#  7870,
#  7875,
#  7878,
#  8296,
#  8306,
#  8704,
#  8733,
#  8864,
#  8904,
#  8909,
#  8961,
#  8999,
#  10555,
#  10741,
#  10804,
#  10810,
#  10921,
#  11021,
#  11217,
#  11312,
#  12738,
#  12851,
#  14226,
#  14356,
#  17678,
#  17682,
#  18399,
#  20235,
#  20239,
#  20289,
#  20303,
#  20342,
#  20629,
#  20664,
#  23486,
#  25882,
#  25992,
#  26078,
#  26523,
#  26815,
#  27074,
#  27190,
#  28118,
#  28576,
#  28595,
#  28923,
#  29799]

# %%
indices_em = []
for palabra in range(len(lista_corpus_contextos)):
    if lista_corpus_contextos[palabra] == 'em':
        indices_em.append(palabra)

# %%
indices_ema = []
for palabra in range(len(lista_corpus_contextos)):
    if lista_corpus_contextos[palabra] == 'ema':
        indices_ema.append(palabra)

# %%
Yem_indices = {'yem':[],'ema':[],'em':[]} 

Yem_indices['yem'] = indices_yem
Yem_indices['em'] = indices_em
Yem_indices['ema'] = indices_ema

# %%
Yem_contextos['yem']
# Out:
# []

# %%
## número de oraciones

Yem_oraciones_num = {Y:len(Yem_oraciones[Y]) for Y in Yem_oraciones.keys()}

# %%
Yem_oraciones_num
# Out:
# {'yem': 0, 'ema': 0, 'em': 0}

# %% [markdown]
# ### Co-ocurrencias

# %%
## Red de co-ocurrencias entre palabras :)
import networkx as nx

def GoW(text_clean):
    
    G=nx.Graph()
    for sentence in text_clean:
        if len(sentence)>1:
            pairs=list(zip(sentence,sentence[1:]))
            for pair in pairs:
                if G.has_edge(pair[0],pair[1])==False:
                    G.add_edge(pair[0],pair[1],weight=1)
                else:
                    x=G[pair[0]][pair[1]]['weight']
                    G[pair[0]][pair[1]]['weight']=x+1
                    
    #Gcc = sorted(nx.connected_components(G), key=len, reverse=True)
    #G0 = G.subgraph(Gcc[0])
    
    return G

# %%
grafos = {}

for Y in diccionario_contextos_presentacion.keys():
    oraciones = diccionario_contextos_presentacion[Y]
    grafos[Y]=GoW(oraciones)

# %%
grafos['yem'].edges(data=True)
# Out:
# EdgeDataView([('domomüna', 'küme', {'weight': 1}), ('küme', 'domosiempre', {'weight': 1}), ('domosiempre', 'acordaniekefuytami', {'weight': 1}), ('acordaniekefuytami', 'ñuke', {'weight': 1}), ('ñuke', 'yem', {'weight': 4}), ('ñuke', 'anaytañi', {'weight': 1}), ('ñuke', 'kimnieydecia', {'weight': 1}), ('ñuke', 'ñi', {'weight': 3}), ('ñuke', 'tañikuse', {'weight': 1}), ('ñuke', 'kalawentuchefengeyagustina', {'weight': 1}), ('yem', 'ñimama', {'weight': 1}), ('yem', 'che', {'weight': 8}), ('yem', 'ta', {'weight': 1}), ('yem', 'laku', {'weight': 6}), ('yem', 'füchakeweychafe', {'weight': 2}), ('yem', 'chuchu', {'weight': 3}), ('yem', 'füchakeche', {'weight': 4}), ('yem', '¿ülkantukefuy', {'weight': 1}), ('yem', 'kuyfi', {'weight': 1}), ('yem', 'püllü', {'weight': 1}), ('yem', 'palu', {'weight': 1}), ('yem', 'ñikuku', {'weight': 1}), ('yem', 'doykimche', {'weight': 1}), ('yem', 'kalawentuchefengeyagustina', {'weight': 1}), ('kimnieydecia', 'pikefuy', {'weight': 1}), ('pikefuy', 'ñimama', {'weight': 1}), ('feychem', 'fey', {'weight': 1}), ('fey', 'famentuniengekeypikefuy', {'weight': 1}), ('famentuniengekeypikefuy', 'ñi', {'weight': 1}), ('ñi', 'rakiduampellkelekepelayengün', {'weight': 1}), ('ñi', 'layalu', {'weight': 1}), ('ñi', 'kimpalu', {'weight': 1}), ('ñi', 'füchakeche', {'weight': 1}), ('ñi', 'mewiñche', {'weight': 1}), ('ñi', 'fücha', {'weight': 1}), ('ñi', 'lawenpikefuyallküñmakefuyta', {'weight': 1}), ('ñi', 'kuse', {'weight': 1}), ('ñi', 'iñche', {'weight': 1}), ('rakiduampellkelekepelayengün', 'taiñ', {'weight': 1}), ('taiñ', 'füchake', {'weight': 1}), ('füchake', 'che', {'weight': 1}), ('che', 'tafüchake', {'weight': 2}), ('che', 'ñifüchake', {'weight': 1}), ('che', 'müley', {'weight': 1}), ('che', 'ngülamfüchake', {'weight': 1}), ('che', 'taiñfüchake', {'weight': 1}), ('che', 'kimniekeykusheke', {'weight': 1}), ('mew', 'feymew', {'weight': 1}), ('mew', 'feychi', {'weight': 1}), ('mew', 'küyen', {'weight': 1}), ('mew', 'ñikuku', {'weight': 1}), ('feymew', 'pellkeley', {'weight': 1}), ('feymew', 'ta', {'weight': 1}), ('pellkeley', 'tafüchake', {'weight': 1}), ('tafüchake', 'mayfemngechiweñengekefuy', {'weight': 1}), ('ñifeypin', 'feyngerkey', {'weight': 1}), ('feyngerkey', 'ta', {'weight': 1}), ('ta', 'ñifüchake', {'weight': 3}), ('ta', 'mapuche', {'weight': 1}), ('ta', 'femngechi', {'weight': 1}), ('ta', 'dewmangekey', {'weight': 1}), ('ta', 'feychi', {'weight': 1}), ('ta', 'chemfalingetukefuy', {'weight': 1}), ('ta', 'ngülamfüchake', {'weight': 1}), ('ñifüchake', 'laku', {'weight': 2}), ('laku', 'tañi', {'weight': 2}), ('laku', 'fücha', {'weight': 1}), ('laku', 'kuse', {'weight': 1}), ('tañi', 'wenüyfey', {'weight': 2}), ('tañi', 'tañi', {'weight': 1}), ('tañi', 'layael', {'weight': 2}), ('tañi', 'kuse', {'weight': 2}), ('tañi', 'kimün', {'weight': 1}), ('tañi', 'füchakeche', {'weight': 4}), ('tañi', 'wimun', {'weight': 1}), ('tañi', 'iñcheiñche', {'weight': 1}), ('tañi', 'ülkantukelafuy', {'weight': 1}), ('tañi', 'renütramkakefielfeyngey', {'weight': 2}), ('tañi', 'amutuael', {'weight': 1}), ('kuse', 'chuchu', {'weight': 1}), ('kuse', 'püllü', {'weight': 1}), ('chuchu', 'tami', {'weight': 1}), ('chuchu', 'ruf', {'weight': 1}), ('feychi', 'layalu', {'weight': 1}), ('feychi', 'eleletew', {'weight': 1}), ('feychi', 'kimün', {'weight': 1}), ('feychi', 'mongentañi', {'weight': 1}), ('mapuche', 'kimpalu', {'weight': 1}), ('wimun', 'tatika', {'weight': 1}), ('tatika', 'tami', {'weight': 1}), ('¿ülkantukefuy', 'katañi', {'weight': 1}), ('katañi', 'ruf', {'weight': 1}), ('dewmangekey', 'tauyew', {'weight': 1}), ('tauyew', 'kuyfi', {'weight': 1}), ('nien', 'pichikalu', {'weight': 1}), ('pichikalu', 'iñcheiñche', {'weight': 1}), ('ülkantuntüfachi', 'ülkantun', {'weight': 1}), ('ülkantun', 'ülkantukelafuy', {'weight': 1}), ('epe', 'amutuael', {'weight': 1}), ('mongentañi', 'palu', {'weight': 1}), ('müley', 'fendemekefuy', {'weight': 1}), ('fendemekefuy', 'tañikuse', {'weight': 1}), ('kiñe', 'pataka', {'weight': 1}), ('pataka', 'm ...

# %%
import matplotlib.pyplot as plt

def plotG_centrality(Y,size):
    
    G = grafos[Y]
    #G0 = G.copy()
    #G0.remove_edges_from(nx.selfloop_edges(G0))
    #G = nx.k_core(G0)
    #G = nx.maximum_spanning_tree(G)
    fig, ax = plt.subplots(dpi=800)
    centrality = nx.pagerank(G,weight='weight')
    ordered_centrality = {k: v for k, v in sorted(centrality.items(), key=lambda item: item[1],reverse=True)}
    labels = {i:i for i in G.nodes() if i in list(zip(*list(ordered_centrality.items())[:50]))[0]}
    pos = nx.spring_layout(G)
    nx.draw_networkx_nodes(G, pos, node_size = [size*x for x in list(centrality.values())], node_color='gold',node_shape='o',alpha=0.95, linewidths=0.1) 
    nx.draw_networkx_edges(G, pos, alpha=0.5,width=0.2,edge_color='k')
    nx.draw_networkx_labels(G,pos,labels,alpha=1,font_size=3.,font_color='k',font_family='monospace')
    plt.title('Red {}'.format(Y),fontsize=8)
    plt.savefig('red_{}.jpg'.format(Y), format='jpg', transparent=True, bbox_inches='tight',dpi=800)
    plt.axis('off')
    plt.show()

# %%
for Y in grafos.keys():
    plotG_centrality(Y,250)

# %%
## función para ranquear co-ocurrencias :)

def ranking(palabra,k):
    red = grafos[palabra]
    return list({k: v for k, v in sorted(dict(red[palabra]).items(), key=lambda item: item[1]['weight'],reverse=True)}.keys())[:k]

# %%
## palabras más cercanas a -em en el corpus misional

for Y in grafos.keys():
    print(Y,ranking(Y,10))
# Out:
# yem ['che', 'laku', 'ñuke', 'füchakeche', 'chuchu', 'ñimama', 'füchakeweychafe', 'kuyfi', 'püllü', 'palu']

# %% [markdown]
# ### Cálculos con el corpus

# %%
##Cuantificación

print('Resultados')
print('  ')  

print('Cantidad de oraciones')
print('  ')  
print(len(palabras))
print('  ')  

print('Cantidad de palabras')


tokens = []
for oracion in palabras:
    for palabra in oracion:
        tokens += [palabra]
print(len(tokens))
print('  ')     


print('Cantidad de palabras únicas')


print(len(set(tokens)))
print('  ')     

print('relación')
    

print(len(set(tokens))/len(tokens))
print('  ')     

#contabilizar yem

Yem = {'yem':0,'ema':0,'em':0} 
for key in Yem.keys():
    Yem[key]=tokens.count(key)

print('Cantidad de yem')
 

print(Yem)
# Out:
# Resultados
#
# Cantidad de oraciones
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-86c71bb1c3b2> in <module>
#       6 print('Cantidad de oraciones')
#       7 print('  ')
# ----> 8 print(len(palabras))
#       9 print('  ')
#      10
#
# NameError: name 'palabras' is not defined

# %%
def revision(WX,YZ): ##recibe una lista y un string que es el que busca
    palabras_transitivas=[] ##defino la lista
    for oracion in WX: ## por cada oración de la lista
        for item in oracion: ##y por cada palabra en la oración
            if item.endswith(YZ): ##si esta termina en el string indicado
                palabras_transitivas+=[item] ##la agrega a la lista
    return palabras_transitivas

# %%
lista = revision(palabras, 'eneu')

# %%
lista
# Out:
# ['piabueneu',
#  'nayaeneu',
#  'alhueyabueneu',
#  'ayúaeneu',
#  'ayuabueneu',
#  'quimaeneu',
#  'gnecanmaaeneu',
#  'genecaaeneu',
#  'llecantuaveneu']

# %%
def dict_contextos(lista_palabras,palabras,k):
    D = {w:[] for w in lista_palabras}
    for oracion in palabras:
        for w in lista_palabras:
            if w in oracion:
                D[w]+=k_anteriores(oracion,w,k)
    return D

# %%
contextos = dict_contextos(lista,palabras,5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-81-84827be19a57> in <module>
# ----> 1 contextos = dict_contextos(lista,palabras,5)
#
# NameError: name 'lista' is not defined

# %%
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

# %%
## pequeña variacion en que palabras ya no es un parámetro

def revision2(YZ): ##recibe una lista y un string que es el que busca
    palabras_transitivas=[] ##defino la lista
    for oracion in palabras: ## por cada oración de la lista
        for item in oracion: ##y por cada palabra en la oración
            if item.endswith(YZ): ##si esta termina en el string indicado
                palabras_transitivas+=[item] ##la agrega a la lista
    return palabras_transitivas

# %%
interact(revision2, YZ='eneu');
# Out:
# interactive(children=(Text(value='eneu', description='YZ'), Output()), _dom_classes=('widget-interact',))
